# %%
import requests
from bs4 import BeautifulSoup
import time
import datetime
import pandas as pd

start  = time.time()

# %%
url = 'https://www.classtok.net/modoo/start_now'
response = requests.get(url)
response
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(response.content, 'html.parser')
soup
# Out:
# <!DOCTYPE html>
#
# <head>
# <script>
#     (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src='https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);})(window,document,'script','dataLayer','GTM-MR4RVDV');
#     </script>
# <!--[if lt IE 9]>
#     <script src="https://app-cdn.enfit.net/assets/js/core/jquery-1.12.4.min.js"></script>
#     <script src="https://app-cdn.enfit.net/assets_new/js/respond.min.js"></script>
# <![endif]-->
# <script src="https://app-cdn.enfit.net/assets/js/core/jquery.min.js"></script>
# <script type="text/javascript">
#         var dataLayer = [];
#     </script>
# <!-- Google Tag Manager -->
# <script>
#         (function(w, d, s, l, i) {
#             w[l] = w[l] || [];
#             w[l].push({
#                 'gtm.start': new Date().getTime(),
#                 event: 'gtm.js'
#             });
#             var f = d.getElementsByTagName(s)[0],
#                 j = d.createElement(s),
#                 dl = l != 'dataLayer' ? '&l=' + l : '';
#             j.async = true;
#             j.src =
#                 'https://www.googletagmanager.com/gtm.js?id=' + i + dl;
#             f.parentNode.insertBefore(j, f);
#         })(window, document, 'script', 'dataLayer', 'GTM-TWM4BVS');
#     </script>
# <!-- End Google Tag Manager -->
# <!-- // firebase polyfill -->
# <script src="https://unpkg.com/core-js-bundle@3.0.1/minified.js" type="text/javascript"></script>
# <meta charset="utf-8"/>
# <meta content="노하우를 배우고 나누는 클래스 마켓 | 언제 어디서나 함께하는 즐거움, 클래스톡" name="description"/>
# <meta content="bLmTyzEezTjR3Tj_5XieuRVdA27XpOuP9rdPKRRGRmg" name="google-site-verification">
# <meta content="" name="p:domain_verify"/>
# <meta content="Copyright © 2019 클래스톡" name="copyright"/>
# <meta content="클래스톡" name="author"/>
# <meta content="index, follow" name="robots"/>
# <meta content="width=device-width,initial-scale=1, minimum-scale=1.0, maximum-scale=1.0, user-scalable=yes, minimal-ui" name="viewport"/>
# <meta content="노하우를 배우고 나누는 클래스 마켓 | 언제 어디서나 함께하는 즐거움, 클래스톡" name="keywords"/>
# <meta content="a1cb7d36efbce34d6f92eaf1895dc9718977b1be" name="naver-site-verification">
# <link href="https://www.classtok.net" rel="canonical"/>
# <link href="https://app-cdn.enfit.net/assets/img/favicons/classtok_favi.png?v=2001230844" rel="shortcut icon"/>
# <link href="https://app-cdn.enfit.net/assets/img/favicons/classtok_favi.ico?v=2001230844" rel="shortcut icon"/>
# <meta content="노하우를 배우고 나누는 클래스 마켓 | 언제 어디서나 함께하는 즐거움, 클래스톡" property="og:type"/>
# <meta content="클래스톡" property="og:title"/>
# <meta content="클래스톡" property="og:site_name"/>
# <meta content="노하우를 배우고 나누는 클래스 마켓 | 언제 어디서나 함께하는 즐거움, 클래스톡" property="og:description"/>
# <meta content="https://app-cdn.enfit.net/img/class/classtok.png" property="og:image"/>
# <meta content="https://www.classtok.net" property="og:url"/>
# <meta content="노하우를 배우고 나누는 클래스 마켓 | 언제 어디서나 함께하는 즐거움, 클래스톡" name="twitter:card"/>
# <meta content="클래스톡" name="twitter:title"/>
# <meta content="노하우를 배우고 나누는 클래스 마켓 | 언제 어디서나 함께하는 즐거움, 클래스톡" name="twitter:description"/>
# <meta content="https://app-cdn.enfit.net/img/class/classtok.png" name="twitter:image"/>
# <meta content="클래스톡" name="twitter:domain"/>
# <meta content="노하우를 배우고 나누는 클래스 마켓 | 언제 어디서나 함께하는 즐거움, 클래스톡" name="facebook:card"/>
# <meta content="클래스톡" name="facebook:title"/>
# <meta content="노하우를 배우고 나누는 클래스 마켓 | 언제 어디서나 함께하는 즐거움, 클래스톡" name="facebook:description"/>
# <meta content="https://app-cdn.enfit.net/img/class/classtok.png" name="facebook:image"/>
# <meta content="클래스톡" name="facebook:domain"/>
# <meta content="1089441441" property="al:ios:app_store_id"/>
# <meta content="클래스톡" property="al:ios:app_name"/>
# <meta content="클래스톡" property="al:android:app_name"/>
# <meta content="https://play.google.com/store/apps/details?id=com.enfit" property="al:android:package"/>
# <meta content=" hB5ETZDTrr1wUshaf7EC6U6vuQpu58AnpPN1cw8K1MI" name="google-site-verification">
# <title>
#                     클래스톡 :: 지금 바로 시작 가능한 클래스
#             </title>
# <link href="https://app-cdn.enfit.net/assets_new/css/style.css" rel="preload" type="text/css"/>
# <link href="https://app-cdn.enfit.net/css/app.css?id=586969d8852a3658d8b5" rel="preload"/>
# <link href="https://app-cdn.enfit.net/assets_new/css/swiper.min.css" rel="stylesheet"/>
# <style>
# /* .page-top .inner { max-width: 960px !important; } */
# .now_box li { margin-bottom: 40px;}
# .header.is-search .header-inner, .header.is-search .inner {
# 	width: 1080px;
# }
# </style>
# <link href="https://app-cdn.enfit.net/assets_new/css/swiper.min.css" rel="prefetch" type="text/css"/>
# <script type="text/javascript">
#         var dataLayar = [];
#
#         // 카카오 픽셀 (카카오 광고 추척)
#         $.getScript('//t1.daumcdn.net/adfit/static/kp.js', function() {
#             kakaoPixel('2823312382539481544').pageView();
#         });
#     </script>
# <!-- Facebook Pixel Code -->
# <script>
#         ! function(f, b, e, v, n, t, s) {
#             if (f.fbq) return;
#             n = f.fbq = function() {
#                 n.callMethod ?
#                     n.callMethod.apply(n, arguments) : n.queue.push(arguments)
#             };
#             if (!f._fbq) f._fbq = n;
#             n.push = n;
#             n.loaded = !0;
#             n.version = '2.0';
#             n.queue = [];
#             t = b.createElement(e);
#             t.async = !0;
#             t.src = v;
#             s = b.getElementsByTagName(e)[0];
#             s.parentNode.insertBefore(t, s)
#         }(window, document, 'script',
#             'https://connect.facebook.net/en_US/fbevents.js');
#         fbq('init', '1008446245925501');
#         fbq('track', 'PageView');
#     </script>
# <script>
#         var __selperAccountId = '8908b03f-0df7-11eb-a969-70106f4bafe6';
#         var __selperFacebookPixelId = '963210724157925';
#         var __selperGoogleAdsConversionId = 'AW-536543892';
#         var __selperGoogleConversionLabel = 'N6aSCL7HxeIBEJSF7P8B';
#         var __selperGoogleAnalyticsMeasurementId = 'UA-161846195-2';
#         (function(w,d,s,l,i) {
#             w[l]=w[l]||[];
#             w[l].push({'gtm.start': new Date().getTime(),event:'gtm.js'});
#             var f=d.getElementsByTagName(s)[0], j=d.createElement(s), dl=l!='dataLayer'?'&l='+l:'';
#             j.async=true;
#             j.src='https://www.googletagmanager.com/gtm.js?id='+i+dl;
#             f.parentNode.insertBefore(j,f);
#         })(window,document,'script','dataLayer','GTM-WJSLMG8');
#     </script>
# <noscript>
# <img height="1" src="https://www.facebook.com/tr?id=1008446245925501&amp;ev=PageView&amp;noscript=1" style="display:none" width="1"/>
# </noscript>
# <!-- End Facebook Pixel Code -->
# <!-- // firebase polyfill -->
# <script src="https://unpkg.com/core-js-bundle@3.0.1/minified.js" type="text/javascript"></script>
# </meta></meta></meta></head>
# <body>
# <!-- Google Tag Manager (noscript) --><noscript><iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-MR4RVDV" style="display:none;visibility:hidden" width="0"></iframe></noscript><!-- End Google Tag Manager (noscript) -->
# <noscript><iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-TWM4BVS" style="display:none;visibility:hidden" width="0"></iframe></noscript>
# <style>
#     .quick-nav {
#         top: auto;
#         bottom: 120px;
#         right: calc(100% / 2 - 750px / 2 - 147px - 20px);
#     }
#
#     @media  screen and (max-width: calc(960px + 55px * 2 + 20px)) {
#         .quick-nav { right: 10px; }
#     }
#
#     @media  screen and (max-width: 960px) {
#
#         footer { padding-bottom: 85px; }
#         .quick-nav { bottom: 95px; }
#     }
#
#     .main_wrap { padding-top: 0px}
# </style>
# <header class="header is-search" id="header">
# <div class="header__box">
# <div class="header-inner">
# <div class="header-left">
# <button class="header__back-button" type="button"></button>
# <button class="header__home-button" type="button"></button>
# <form action="/class/search" class="header__search-form" id="searchClass" method="GET">
# <label class="header__search-label" for="searchKey">
# <input autocomplete="off" class="header__search-input" id="searchKey" name="searchKey" placeholder="클래스나 코치를 검색해보세요." type="search"/>
# <input class="header__search-submit" type="submit"/>
# </label>
# </form>
# </div>
# <div class="header-right">
# <button class="header__search-button" id="serchModalPopButton" type="button">클래스 검색</button>
# <a class="header__class-apply-link" href="/class/open" title="클래스톡 클래스 개설신청하기">클래스 개설</a>
# <a class="header__login" href="/modoo/login" title="클래스톡 로그인">로그인</a>
# </div>
# </div>
# </div>
# <div class="header__shadow"></div>
# </header>
# <div class="search-modal" id="searchModal">
# <div class="search-modal-header">
# <div class="inner">
# <div class="search-modal__search-wrapper">
# <form class="search-modal__search-form" id="searchModalForm">
# <label class="search-modal__search-label" for="searchModalInput">
# <input autocomplete="off" class="search-modal__search-input" id="searchModalInput" name="searchModalInput" placeholder="클래스 또는 코치를 검색해보세요." type="search"/>
# <input class="search-modal__search-submit" id="searchModalSubmit" type="submit"/>
# </label>
# </form>
# </div>
# <button class="search-modal__close-button" id="searchModalCloseButton" type="button">닫기</button>
# </div>
# </div>
# <div class="search-modal-body">
# <div class="inner">
# <div class="search-modal-recent-keyword" id="searchReceentWrapper">
# <h2 class="search-modal__title">최근 검색어</h2>
# <ul class="search-modal__keyword-list" id="searchRecentKeyword">
# <li class="search-modal__keyword-item">
# <a class="search-modal__keyword-link" href="/class/search?searchKey=##keyword##">###keyword##</a>
# </li>
# </ul>
# </div>
# <div class="search-modal-popular-keyword" id="searchPopularWrapper">
# <h2 class="search-modal__title">실시간 인기 관심사</h2>
# <ul class="search-modal__keyword-list" id="searchPopularKeyword">
# <li class="search-modal__keyword-item">
# <a class="search-modal__keyword-link" href="/class/search?searchKey=##keyword##">###keyword##</a>
# </li>
# </ul>
# </div>
# <div class="search-modal-category">
# <h2 class="search-modal__title">이런 관심사는 어때요?</h2>
# <ul class="search-modal__category-list" id="searchCategoryList">
# <li class="search-modal__category-item">
# <a class="search-modal__category-link" href="/class/search?searchKey=##link##">
# <div class="search-modal__category-img" style="background-image: url(##photo##);"></div>
# </a>
# <a class="search-modal__category-link" href="/class/search?searchKey=##link##">##keyword##</a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# <!-- main wrap -->
# <div class="main_wrap">
# <div class="product_list">
# <div class="now_box product_box clear">
# <h1>하고 싶은 클래스를 찾아보세요<br/><b>지금 신청 가능한 클래스</b></h1>
# <ul>
# <div class="swiper-container">
# <li class="swiper-slide">
# <div>
# <p class="btn_wish have_click_event" data-id="1756"><img alt="찜하기" src="https://app-cdn.enfit.net/img/class/icon_heart_2.png"/></p>
# <a href="/class/classDetail/1756">
# <div class="product_img_wrap"><div class="product_img" style="background-image: url('https://app-cdn.enfit.net/uploads/photo_800/a9e6EWKMVzAu9JY3.jpg?width=500&amp;height=500');"></div></div>
# </a>
# <a class="product_info" href="/class/classDetail/1756">
# <span>스피치 · 명이</span>
# <h2>똑 부러지게 말하는 내 아이를 위한 키즈 스피치</h2>
# <div class="price_info">
# <b><span>월</span>35,000원</b>
# <span class="percent">61% 할인</span>
# </div>
# <div class="product_star">
# <img alt="1점 별 아이콘" src="https://app-cdn.enfit.net/img/class/icon_star_1.png"> 5 (5)
# 									    									</img></div>
# <div class="participants">참여 멤버 82</div>
# </a>
# </div>
# </li>
# <li class="swiper-slide">
# <div>
# <p class="btn_wish have_click_event" data-id="1612"><img alt="찜하기" src="https://app-cdn.enfit.net/img/class/icon_heart_0.png"/></p>
# <a href="/class/classDetail/1612">
# <div class="product_img_wrap"><div class="product_img" style="background-image: url('https://app-cdn.enfit.net/uploads/photo_800/WGWgnpNv0W9WjcAC.jpg?width=500&amp;height=500');"></div></div>
# </a>
# <a class="product_info" href="/class/classDetail/1612">
# <span>외국어 · 영하쌤</span>
# <h2>[현직 1타 강사] 최단기 토익 600점 완성반 - RC편</h2>
# <div class="price_info">
# <b><span>월</span>35,000원</b>
# <span class="percent">60.6% 할인</span>
# </div>
# <div class="product_star">
# <img alt="1점 별 아이콘" src="https://app-cdn.enfit.net/img/class/icon_star_1.png"> 4.8 (5)
# 									    									</img></div>
# <div class="participants">참여 멤버 41</div>
# </a>
# </div>
# </li>
# <li class="swiper-slide">
# <div>
# <p class="btn_wish have_click_event" data-id="1235"><img alt="찜하기" src="https://app-cdn.enfit.net/img/class/icon_heart_0.png"/></p>
# <a href="/class/classDetail/1235">
# <div class="product_img_wrap"><div class="product_img" style="background-image: url('https://app-cdn.enfit.net/uploads/photo_800/h6bp5vaal1FzG7xK.jpg?width=500&amp;height=500');"></div></div>
# </a>
# <a class="product_info" href="/class/classDetail/1235">
# <span>요리 · 쿡킴</span>
# <h2>쉽게 만드는 레스토랑급 퓨전요리</h2>
# <div class="price_info">
# <b><span>월</span>25,000원</b>
# <span class="percent">68.3% 할인</span>
# </div>
# <div class="product_star">
# </div>
# <div class="participants">참여 멤버 6</div>
# </a>
# </div>
# </li>
# <li class="swiper-slide">
# <div>
# <p class="btn_wish have_click_event" data-id="1670"><img alt="찜하기" src="https://app-cdn.enfit.net/img/class/icon_heart_2.png"/></p>
# <a href="/class/classDetail/1670">
# <div class="product_img_wrap"><div class="product_img" style="background-image: url('https://app-cdn.enfit.net/uploads/photo_800/409FIoT0vKC09Qlm.jpg?width=500&amp;height=500');"></div></div>
# </a>
# <a class="product_info" href="/class/classDetail/1670">
# <span>취업 · 취업전문가문근영</span>
# <h2>[경력10년]나의 가치를 인정받는 취업 합격반(자소서,면접)</h2>
# <div class="price_info">
# <b><span>월</span>39,800원</b>
# <span class="percent">59.7% 할인</span>
# </div>
# <div class="product_star">
# <img alt="1점 별 아이콘" src="https://app-cdn.enfit.net/img/class/icon_star_1.png"> 4.6 (14)
# 									    									</img></div>
# <div class="participants">참여 멤버 43</div>
# </a>
# </div>
# </li>
# <li class="swiper-slide">
# <div>
# <p class="btn_wish have_click_event" data-id="3317"><img alt="찜하기" src="https://app-cdn.enfit.net/img/class/icon_heart_0.png"/></p>
# <a href="/class/classDetail/3317">
# <div class="product_img_wrap"><div class="product_img" style="background-image: url('https://app-cdn.enfit.net/uploads/photo_800/TgwA6KpbEPqX6sx7.png?width=500&amp;height=500');"></div></div>
# </a>
# <a class="product_info" href="/class/classDetail/3317">
# <span>외국어 · 오픽강사강보경</span>
# <h2>씨리얼 오픽 돌발주제</h2>
# <div class="price_info">
# <b><span>월</span>40,000원</b>
# <span class="percent">60% 할인</span>
# </div>
# <div class="product_star">
# </div>
# </a>
# </div>
# </li>
# <li class="swiper-slide">
# <div>
# <p class="btn_wish have_click_event" data-id="2755"><img alt="찜하기" src="https://app-cdn.enfit.net/img/class/icon_heart_0.png"/></p>
# <a href="/class/classDetail/2755">
# <div class="product_img_wrap"><div class="product_img" style="background-image: url('https://app-cdn.enfit.net/uploads/photo_800/y3IyqanyP7EEhu6X.png?width=500&amp;height=500');"></div></div>
# </a>
# <a class="product_info" href="/class/classDetail/2755">
# <span>스피치 · ChoiCindy❤️</span>
# <h2>현직 아나운서에게 배우는 말 잘하는 스피치</h2>
# <div class="price_info">
# <b><span>월</span>17,000원</b>
# <span class="percent">83% 할인</span>
# </div>
# <div class="product_star">
# </div>
# <div class="participants">참여 멤버 1</div>
# </a>
# </div>
# </li>
# <li class="swiper-slide">
# <div>
# <p class="btn_wish have_click_event" data-id="3357"><img alt="찜하기" src="https://app-cdn.enfit.net/img/class/icon_heart_0.png"/></p>
# <a href="/class/classDetail/3357">
# <div class="product_img_wrap"><div class="product_img" style="background-image: url('https://app-cdn.enfit.net/uploads/photo_800/UAmRIZtc3LO9Evad.png?width=500&amp;height=500');"></div></div>
# </a>
# <a class="product_info" href="/class/classDetail/3357">
# <span>외국어 · 토스강사송예지</span>
# <h2>씨리얼 신토익 스피킹 실전 - Actual Test 2회</h2>
# <div class="price_info">
# <b><span>월</span>17,000원</b>
# <span class="percent">58% 할인</span>
# </div>
# <div class="product_star">
# </div>
# </a>
# </div>
# </li>
# <li class="swiper-slide">
# <div>
# <p class="btn_wish have_click_event" data-id="1673"><img alt="찜하기" src="https://app-cdn.enfit.net/img/class/icon_heart_2.png"/></p>
# <a href="/class/classDetail/1673">
# <div class="product_img_wrap"><div class="product_img" style="background-image: url('https://app-cdn.enfit.net/uploads/photo_800/SHEbiKJ7pBOAVAMx.png?width=500&amp;height=500');"></div></div>
# </a>
# <a class="product_info" href="/class/classDetail/1673">
# <span>음악 · 에스민</span>
# <h2>'누구나 쉽게 음악을 만들 수 있어요! 큐베이스로 음악 만들기</h2>
# <div class="price_info">
# <b><span>월</span>39,000원</b>
# <span class="percent">60.6% 할인</span>
# </div>
# <div class="product_star">
# </div>
# <div class="participants">참여 멤버 4</div>
# </a>
# </div>
# </li>
# <li class="swiper-slide">
# <div>
# <p class="btn_wish have_click_event" data-id="2007"><img alt="찜하기" src="https://app-cdn.enfit.net/img/class/icon_heart_2.png"/></p>
# <a href="/class/classDetail/2007">
# <div class="product_img_wrap"><div class="product_img" style="background-image: url('https://app-cdn.enfit.net/uploads/photo_800/8ubqAFe7g0l1gFwG.jpg?width=500&amp;height=500');"></div></div>
# </a>
# <a class="product_info" href="/class/classDetail/2007">
# <span>댄스 · 라틴핏 댄서윰</span>
# <h2>음악과 함께하는 재미있는 라틴핏 다이어트</h2>
# <div class="price_info">
# <b><span>월</span>35,000원</b>
# <span class="percent">61% 할인</span>
# </div>
# <div class="product_star">
# <img alt="1점 별 아이콘" src="https://app-cdn.enfit.net/img/class/icon_star_1.png"> 5 (1)
# 									    									</img></div>
# <div class="participants">참여 멤버 39</div>
# </a>
# </div>
# </li>
# <li class="swiper-slide">
# <div>
# <p class="btn_wish have_click_event" data-id="2900"><img alt="찜하기" src="https://app-cdn.enfit.net/img/class/icon_heart_0.png"/></p>
# <a href="/class/classDetail/2900">
# <div class="product_img_wrap"><div class="product_img" style="background-image: url('https://app-cdn.enfit.net/uploads/photo_800/gwFYDyQIwjfI4g5e.jpg?width=500&amp;height=500');"></div></div>
# </a>
# <a class="product_info" href="/class/classDetail/2900">
# <span>그림 · 그림책작가박찬주</span>
# <h2>아크릴 마음치유 클래스</h2>
# <div class="price_info">
# <b><span>월</span>14,000원</b>
# <span class="percent">84% 할인</span>
# </div>
# <div class="product_star">
# </div>
# <div class="participants">참여 멤버 9</div>
# </a>
# </div>
# </li>
# <li class="swiper-slide">
# <div>
# <p class="btn_wish have_click_event" data-id="2512"><img alt="찜하기" src="https://app-cdn.enfit.net/img/class/icon_heart_2.png"/></p>
# <a href="/class/classDetail/2512">
# <div class="product_img_wrap"><div class="product_img" style="background-image: url('https://app-cdn.enfit.net/uploads/photo_800/w2AoD3oH3znIjeOD.png?width=500&amp;height=500');"></div></div>
# </a>
# <a class="product_info" href="/class/classDetail/2512">
# <span>운동 · hj</span>
# <h2>거북목, 어깨통증 타파! 바른자세 회복운동</h2>
# <div class="price_info">
# <b><span>월</span>30,000원</b>
# <span class="percent">62% 할인</span>
# </div>
# <div class="product_star">
# <img alt="1점 별 아이콘" src="https://app-cdn.enfit.net/img/class/icon_star_1.png"> 5 (1)
# 									    									</img></div>
# <div class="participants">참여 멤버 15</div>
# </a>
# </div>
# </li>
# <li class="swiper-slide">
# <div>
# <p class="btn_wish have_click_event" data-id="1146"><img alt="찜하기" src="https://app-cdn.enfit.net/img/class/icon_heart_2.png"/></p>
# <a href="/class/classDetail/1146">
# <div class="product_img_wrap"><div class="product_img" style="background-image: url('https://app-cdn.enfit.net/uploads/photo_800/aUOP3jdCczRPF17d.jpg?width=500&amp;height=500');"></div></div>
# </a>
# <a class="product_info" href="/class/classDetail/1146">
# <span>영상편집 · 치하키</span>
# <h2>유튜버 치하키의 핸드폰으로 영상 만들기 : 루마퓨전</h2>
# <div class="price_info">
# <b><span>월</span>29,000원</b>
# <span class="percent">63.2% 할인</span>
# </div>
# <div class="product_star">
# <img alt="1점 별 아이콘" src="https://app-cdn.enfit.net/img/class/icon_star_1.png"> 4.8 (88)
# 									    									</img></div>
# <div class="participants">참여 멤버 383</div>
# </a>
# </div>
# </li>
# <li class="swiper-slide">
# <div>
# <p class="btn_wish have_click_event" data-id="1966"><img alt="찜하기" src="https://app-cdn.enfit.net/img/class/icon_heart_2.png"/></p>
# <a href="/class/classDetail/1966">
# <div class="product_img_wrap"><div class="product_img" style="background-image: url('https://app-cdn.enfit.net/uploads/photo_800/jtr28ShMk7KC0hdU.jpg?width=500&amp;height=500');"></div></div>
# </a>
# <a class="product_info" href="/class/classDetail/1966">
# <span>DIY · 수록</span>
# <h2>프랑스 자수로 수놓는 특별한 선물, 입체꽃 웨딩 액자</h2>
# <div class="price_info">
# <b><span>월</span>38,900원</b>
# <span class="percent">61% 할인</span>
# </div>
# <div class="product_star">
# <img alt="1점 별 아이콘" src="https://app-cdn.enfit.net/img/class/icon_star_1.png"> 5 (7)
# 									    									</img></div>
# <div class="participants">참여 멤버 10</div>
# </a>
# </div>
# </li>
# <li class="swiper-slide">
# <div>
# <p class="btn_wish have_click_event" data-id="1211"><img alt="찜하기" src="https://app-cdn.enfit.net/img/class/icon_heart_0.png"/></p>
# <a href="/class/classDetail/1211">
# <div class="product_img_wrap"><div class="product_img" style="background-image: url('https://app-cdn.enfit.net/uploads/photo_800/4GH5tlyTf0hpkOIM.jpg?width=500&amp;height=500');"></div></div>
# </a>
# <a class="product_info" href="/class/classDetail/1211">
# <span>음악 · 민우쌤</span>
# <h2>노래하는 기타레슨</h2>
# <div class="price_info">
# <b><span>월</span>33,900원</b>
# <span class="percent">61.9% 할인</span>
# </div>
# <div class="product_star">
# <img alt="1점 별 아이콘" src="https://app-cdn.enfit.net/img/class/icon_star_1.png"> 4.5 (6)
# 									    									</img></div>
# <div class="participants">참여 멤버 10</div>
# </a>
# </div>
# </li>
# <li class="swiper-slide">
# <div>
# <p class="btn_wish have_click_event" data-id="2583"><img alt="찜하기" src="https://app-cdn.enfit.net/img/class/icon_heart_0.png"/></p>
# <a href="/class/classDetail/2583">
# <div class="product_img_wrap"><div class="product_img" style="background-image: url('https://app-cdn.enfit.net/uploads/photo_800/eRcAthwkRxwmbDMC.jpg?width=500&amp;height=500');"></div></div>
# </a>
# <a class="product_info" href="/class/classDetail/2583">
# <span>창업 · 김경미</span>
# <h2>[ 65억 창업 선배가 들려주는 사업 실전 노하우 ]</h2>
# <div class="price_info">
# <b><span>월</span>39,000원</b>
# <span class="percent">51% 할인</span>
# </div>
# <div class="product_star">
# </div>
# <div class="participants">참여 멤버 10</div>
# </a>
# </div>
# </li>
# <li class="swiper-slide">
# <div>
# <p class="btn_wish have_click_event" data-id="1856"><img alt="찜하기" src="https://app-cdn.enfit.net/img/class/icon_heart_2.png"/></p>
# <a href="/class/classDetail/1856">
# <div class="product_img_wrap"><div class="product_img" style="background-image: url('https://app-cdn.enfit.net/uploads/photo_800/1qKmWKNiMBRcuzSQ.jpg?width=500&amp;height=500');"></div></div>
# </a>
# <a class="product_info" href="/class/classDetail/1856">
# <span>음료 · 러블리은</span>
# <h2>하루 1잔으로 힐링하는 시간, 나만의 홈카페</h2>
# <div class="price_info">
# <b><span>월</span>42,000원</b>
# <span class="percent">58% 할인</span>
# </div>
# <div class="product_star">
# <img alt="1점 별 아이콘" src="https://app-cdn.enfit.net/img/class/icon_star_1.png"> 5 (3)
# 									    									</img></div>
# <div class="participants">참여 멤버 22</div>
# </a>
# </div>
# </li>
# <li class="swiper-slide">
# <div>
# <p class="btn_wish have_click_event" data-id="2305"><img alt="찜하기" src="https://app-cdn.enfit.net/img/class/icon_heart_0.png"/></p>
# <a href="/class/classDetail/2305">
# <div class="product_img_wrap"><div class="product_img" style="background-image: url('https://app-cdn.enfit.net/uploads/photo_800/2rGTfW4kiejYvUtg.png?width=500&amp;height=500');"></div></div>
# </a>
# <a class="product_info" href="/class/classDetail/2305">
# <span>부동산 · 허준열</span>
# <h2>부동산 폭로영상 및 실전투자요령</h2>
# <div class="price_info">
# <b><span>월</span>39,000원</b>
# <span class="percent">56% 할인</span>
# </div>
# <div class="product_star">
# </div>
# <div class="participants">참여 멤버 4</div>
# </a>
# </div>
# </li>
# <li class="swiper-slide">
# <div>
# <p class="btn_wish have_click_event" data-id="2575"><img alt="찜하기" src="https://app-cdn.enfit.net/img/class/icon_heart_0.png"/></p>
# <a href="/class/classDetail/2575">
# <div class="product_img_wrap"><div class="product_img" style="background-image: url('https://app-cdn.enfit.net/uploads/photo_800/S81Ch4qnmm4h56ni.png?width=500&amp;height=500');"></div></div>
# </a>
# <a class="product_info" href="/class/classDetail/2575">
# <span>다이어트 · 김관장박사장</span>
# <h2>내 몸을 지키고, 살도 빠지는 주짓수의 모든 것</h2>
# <div class="price_info">
# <b><span>월</span>29,500원</b>
# <span class="percent">63% 할인</span>
# </div>
# <div class="product_star">
# </div>
# <div class="participants">참여 멤버 4</div>
# </a>
# </div>
# </li>
# <li class="swiper-slide">
# <div>
# <p class="btn_wish have_click_event" data-id="1779"><img alt="찜하기" src="https://app-cdn.enfit.net/img/class/icon_heart_2.png"/></p>
# <a href="/class/classDetail/1779">
# <div class="product_img_wrap"><div class="product_img" style="background-image: url('https://app-cdn.enfit.net/uploads/photo_800/3wG9D02kldnWzPqb.png?width=500&amp;height=500');"></div></div>
# </a>
# <a class="product_info" href="/class/classDetail/1779">
# <span>외국어 · 도앵</span>
# <h2>델프 정복! 취업, 면접 정복! 프랑스어 배우기!</h2>
# <div class="price_info">
# <b><span>월</span>29,800원</b>
# <span class="percent">67% 할인</span>
# </div>
# <div class="product_star">
# </div>
# <div class="participants">참여 멤버 10</div>
# </a>
# </div>
# </li>
# <li class="swiper-slide">
# <div>
# <p class="btn_wish have_click_event" data-id="1254"><img alt="찜하기" src="https://app-cdn.enfit.net/img/class/icon_heart_2.png"/></p>
# <a href="/class/classDetail/1254">
# <div class="product_img_wrap"><div class="product_img" style="background-image: url('https://app-cdn.enfit.net/uploads/photo_800/G4W9zHfiZIOBFYpb.jpg?width=500&amp;height=500');"></div></div>
# </a>
# <a class="product_info" href="/class/classDetail/1254">
# <span>리본 · 핸드리</span>
# <h2>손으로 그리는 나만의 특별한 리본 공예</h2>
# <div class="price_info">
# <b><span>월</span>37,800원</b>
# <span class="percent">56% 할인</span>
# </div>
# <div class="product_star">
# <img alt="1점 별 아이콘" src="https://app-cdn.enfit.net/img/class/icon_star_1.png"> 5 (14)
# 									    									</img></div>
# <div class="participants">참여 멤버 59</div>
# </a>
# </div>
# </li>
# <li class="swiper-slide">
# <div>
# <p class="btn_wish have_click_event" data-id="1640"><img alt="찜하기" src="https://app-cdn.enfit.net/img/class/icon_heart_2.png"/></p>
# <a href="/class/classDetail/1640">
# <div class="product_img_wrap"><div class="product_img" style="background-image: url('https://app-cdn.enfit.net/uploads/photo_800/Hn9S8L4bo5kDvEPP.png?width=500&amp;height=500');"></div></div>
# </a>
# <a class="product_info" href="/class/classDetail/1640">
# <span>드로잉 · 혜인</span>
# <h2>소중한 순간을 그림으로, 아이패드 드로잉</h2>
# <div class="price_info">
# <b><span>월</span>33,000원</b>
# <span class="percent">56% 할인</span>
# </div>
# <div class="product_star">
# <img alt="1점 별 아이콘" src="https://app-cdn.enfit.net/img/class/icon_star_1.png"> 4.8 (16)
# 									    									</img></div>
# <div class="participants">참여 멤버 254</div>
# </a>
# </div>
# </li>
# <li class="swiper-slide">
# <div>
# <p class="btn_wish have_click_event" data-id="2299"><img alt="찜하기" src="https://app-cdn.enfit.net/img/class/icon_heart_2.png"/></p>
# <a href="/class/classDetail/2299">
# <div class="product_img_wrap"><div class="product_img" style="background-image: url('https://app-cdn.enfit.net/uploads/photo_800/Gs7c81qLoDQXHVA3.jpg?width=500&amp;height=500');"></div></div>
# </a>
# <a class="product_info" href="/class/classDetail/2299">
# <span>취미 · 전범석</span>
# <h2>다양한 일상용품을 이용한 마술 배우기</h2>
# <div class="price_info">
# <b><span>월</span>29,000원</b>
# <span class="percent">63% 할인</span>
# </div>
# <div class="product_star">
# </div>
# <div class="participants">참여 멤버 18</div>
# </a>
# </div>
# </li>
# <li class="swiper-slide">
# <div>
# <p class="btn_wish have_click_event" data-id="2297"><img alt="찜하기" src="https://app-cdn.enfit.net/img/class/icon_heart_2.png"/></p>
# <a href="/class/classDetail/2297">
# <div class="product_img_wrap"><div class="product_img" style="background-image: url('https://app-cdn.enfit.net/uploads/photo_800/VkSwNZLUr8fFvZZ3.png?width=500&amp;height=500');"></div></div>
# </a>
# <a class="product_info" href="/class/classDetail/2297">
# <span>유튜브 · 김다은</span>
# <h2>돈과 커리어를 모두 잡는 콘텐츠 크리에이터가 되는 노하우!</h2>
# <div class="price_info">
# <b><span>월</span>38,000원</b>
# <span class="percent">52% 할인</span>
# </div>
# <div class="product_star">
# <img alt="1점 별 아이콘" src="https://app-cdn.enfit.net/img/class/icon_star_1.png"> 5 (5)
# 									    									</img></div>
# <div class="participants">참여 멤버 30</div>
# </a>
# </div>
# </li>
# <li class="swiper-slide">
# <div>
# <p class="btn_wish have_click_event" data-id="3495"><img alt="찜하기" src="https://app-cdn.enfit.net/img/class/icon_heart_0.png"/></p>
# <a href="/class/classDetail/3495">
# <div class="product_img_wrap"><div class="product_img" style="background-image: url('https://app-cdn.enfit.net/uploads/photo_800/E0hxoqxW400gtJDV.jpg?width=500&amp;height=500');"></div></div>
# </a>
# <a class="product_info" href="/class/classDetail/3495">
# <span>마케팅 · 이종범</span>
# <h2>스타트업을 위한 마케팅 전략</h2>
# <div class="price_info">
# <b><span>월</span>30,000원</b>
# <span class="percent">66% 할인</span>
# </div>
# <div class="product_star">
# </div>
# <div class="participants">참여 멤버 1</div>
# </a>
# </div>
# </li>
# <li class="swiper-slide">
# <div>
# <p class="btn_wish have_click_event" data-id="2892"><img alt="찜하기" src="https://app-cdn.enfit.net/img/class/icon_heart_2.png"/></p>
# <a href="/class/classDetail/2892">
# <div class="product_img_wrap"><div class="product_img" style="background-image: url('https://app-cdn.enfit.net/uploads/photo_800/Kgs5HhsGLLtuDn5p.jpg?width=500&amp;height=500');"></div></div>
# </a>
# <a class="product_info" href="/class/classDetail/2892">
# <span>운동 · 유미</span>
# <h2>기초공사 탄탄! 우리 몸을 리셋하는 필라테스</h2>
# <div class="price_info">
# <b><span>월</span>25,000원</b>
# <span class="percent">68% 할인</span>
# </div>
# <div class="product_star">
# </div>
# <div class="participants">참여 멤버 16</div>
# </a>
# </div>
# </li>
# <li class="swiper-slide">
# <div>
# <p class="btn_wish have_click_event" data-id="853"><img alt="찜하기" src="https://app-cdn.enfit.net/img/class/icon_heart_2.png"/></p>
# <a href="/class/classDetail/853">
# <div class="product_img_wrap"><div class="product_img" style="background-image: url('https://app-cdn.enfit.net/uploads/photo_800/LCGzopLc9mgoBGVJ.png?width=500&amp;height=500');"></div></div>
# </a>
# <a class="product_info" href="/class/classDetail/853">
# <span>다이어트 · 조싀앤바믜</span>
# <h2>텐션UP! 신나고 즐거운 다이어트 댄스 클래스</h2>
# <div class="price_info">
# <b><span>월</span>29,000원</b>
# </div>
# <div class="product_star">
# <img alt="1점 별 아이콘" src="https://app-cdn.enfit.net/img/class/icon_star_1.png"> 4.7 (186)
# 									    									</img></div>
# <div class="participants">참여 멤버 1,061</div>
# </a>
# </div>
# </li>
# <li class="swiper-slide">
# <div>
# <p class="btn_wish have_click_event" data-id="3155"><img alt="찜하기" src="https://app-cdn.enfit.net/img/class/icon_heart_0.png"/></p>
# <a href="/class/classDetail/3155">
# <div class="product_img_wrap"><div class="product_img" style="background-image: url('https://app-cdn.enfit.net/uploads/photo_800/8obE3hdePmZIoFJb.png?width=500&amp;height=500');"></div></div>
# </a>
# <a class="product_info" href="/class/classDetail/3155">
# <span>유튜브 · 한정혜</span>
# <h2>슬기로운 유튜브 생활</h2>
# <div class="price_info">
# <b><span>월</span>39,000원</b>
# <span class="percent">51% 할인</span>
# </div>
# <div class="product_star">
# <img alt="1점 별 아이콘" src="https://app-cdn.enfit.net/img/class/icon_star_1.png"> 5 (1)
# 									    									</img></div>
# <div class="participants">참여 멤버 50</div>
# </a>
# </div>
# </li>
# <li class="swiper-slide">
# <div>
# <p class="btn_wish have_click_event" data-id="2464"><img alt="찜하기" src="https://app-cdn.enfit.net/img/class/icon_heart_0.png"/></p>
# <a href="/class/classDetail/2464">
# <div class="product_img_wrap"><div class="product_img" style="background-image: url('https://app-cdn.enfit.net/uploads/photo_800/BID2FQQOjxq6vpUO.jpg?width=500&amp;height=500');"></div></div>
# </a>
# <a class="product_info" href="/class/classDetail/2464">
# <span>드로잉 · 김홍석</span>
# <h2>인스타그램에 올리고 싶은 디지털 드로잉</h2>
# <div class="price_info">
# <b><span>월</span>10,000원</b>
# <span class="percent">87% 할인</span>
# </div>
# <div class="product_star">
# </div>
# <div class="participants">참여 멤버 22</div>
# </a>
# </div>
# </li>
# <li class="swiper-slide">
# <div>
# <p class="btn_wish have_click_event" data-id="3205"><img alt="찜하기" src="https://app-cdn.enfit.net/img/class/icon_heart_2.png"/></p>
# <a href="/class/classDetail/3205">
# <div class="product_img_wrap"><div class="product_img" style="background-image: url('https://app-cdn.enfit.net/uploads/photo_800/QFTwncT3FV8eBSim.png?width=500&amp;height=500');"></div></div>
# </a>
# <a class="product_info" href="/class/classDetail/3205">
# <span>스피치 · 다이아제이</span>
# <h2>발성전문가의 뛰어나되 유연한 진짜 스피치 강의</h2>
# <div class="price_info">
# <b><span>월</span>49,000원</b>
# <span class="percent">62% 할인</span>
# </div>
# <div class="product_star">
# </div>
# <div class="participants">참여 멤버 14</div>
# </a>
# </div>
# </li>
# <li class="swiper-slide">
# <div>
# <p class="btn_wish have_click_event" data-id="2511"><img alt="찜하기" src="https://app-cdn.enfit.net/img/class/icon_heart_2.png"/></p>
# <a href="/class/classDetail/2511">
# <div class="product_img_wrap"><div class="product_img" style="background-image: url('https://app-cdn.enfit.net/uploads/photo_800/pvxx4dKJLHu8oNxK.jpg?width=500&amp;height=500');"></div></div>
# </a>
# <a class="product_info" href="/class/classDetail/2511">
# <span>스마트워크 · 스마트손선생 손영복</span>
# <h2>'프로 일잘러 되기' 스마트워크 클래스</h2>
# <div class="price_info">
# <b><span>월</span>29,000원</b>
# <span class="percent">63% 할인</span>
# </div>
# <div class="product_star">
# </div>
# <div class="participants">참여 멤버 4</div>
# </a>
# </div>
# </li>
# <li class="swiper-slide">
# <div>
# <p class="btn_wish have_click_event" data-id="3064"><img alt="찜하기" src="https://app-cdn.enfit.net/img/class/icon_heart_2.png"/></p>
# <a href="/class/classDetail/3064">
# <div class="product_img_wrap"><div class="product_img" style="background-image: url('https://app-cdn.enfit.net/uploads/photo_800/uiMuzkjaJKwZJ1Yx.jpg?width=500&amp;height=500');"></div></div>
# </a>
# <a class="product_info" href="/class/classDetail/3064">
# <span> · 슈가쌤</span>
# <h2>아이와 함께 만드는 미니 슈가 케이크</h2>
# <div class="price_info">
# <b><span>월</span>10,000원</b>
# <span class="percent">87% 할인</span>
# </div>
# <div class="product_star">
# </div>
# <div class="participants">참여 멤버 6</div>
# </a>
# </div>
# </li>
# <li class="swiper-slide">
# <div>
# <p class="btn_wish have_click_event" data-id="2263"><img alt="찜하기" src="https://app-cdn.enfit.net/img/class/icon_heart_0.png"/></p>
# <a href="/class/classDetail/2263">
# <div class="product_img_wrap"><div class="product_img" style="background-image: url('https://app-cdn.enfit.net/uploads/photo_800/2RTGInCNX960sShT.jpg?width=500&amp;height=500');"></div></div>
# </a>
# <a class="product_info" href="/class/classDetail/2263">
# <span>라이프스타일 · 명상호흡ㅣ코치</span>
# <h2>불안감 치유명상 클래스 (순환체조 호흡명상)</h2>
# <div class="price_info">
# <b><span>월</span>5,000원</b>
# <span class="percent">83% 할인</span>
# </div>
# <div class="product_star">
# </div>
# <div class="participants">참여 멤버 1</div>
# </a>
# </div>
# </li>
# <li class="swiper-slide">
# <div>
# <p class="btn_wish have_click_event" data-id="2291"><img alt="찜하기" src="https://app-cdn.enfit.net/img/class/icon_heart_0.png"/></p>
# <a href="/class/classDetail/2291">
# <div class="product_img_wrap"><div class="product_img" style="background-image: url('https://app-cdn.enfit.net/uploads/photo_800/WKQXFGA5trsmqGGB.png?width=500&amp;height=500');"></div></div>
# </a>
# <a class="product_info" href="/class/classDetail/2291">
# <span>드로잉 · 퀸맵n캄비</span>
# <h2>명화 그림체로 그리는 아크릴화 작품 만들기</h2>
# <div class="price_info">
# <b><span>월</span>38,000원</b>
# <span class="percent">52% 할인</span>
# </div>
# <div class="product_star">
# <img alt="1점 별 아이콘" src="https://app-cdn.enfit.net/img/class/icon_star_1.png"> 5 (1)
# 									    									</img></div>
# <div class="participants">참여 멤버 8</div>
# </a>
# </div>
# </li>
# <li class="swiper-slide">
# <div>
# <p class="btn_wish have_click_event" data-id="1398"><img alt="찜하기" src="https://app-cdn.enfit.net/img/class/icon_heart_0.png"/></p>
# <a href="/class/classDetail/1398">
# <div class="product_img_wrap"><div class="product_img" style="background-image: url('https://app-cdn.enfit.net/uploads/photo_800/d0O8UUU5eI6sRUaJ.jpg?width=500&amp;height=500');"></div></div>
# </a>
# <a class="product_info" href="/class/classDetail/1398">
# <span>DIY · 더하다마크라메</span>
# <h2>손으로 한땀한땀, 감성 인테리어 마크라메 배우기</h2>
# <div class="price_info">
# <b><span>월</span>45,000원</b>
# <span class="percent">62.5% 할인</span>
# </div>
# <div class="product_star">
# <img alt="1점 별 아이콘" src="https://app-cdn.enfit.net/img/class/icon_star_1.png"> 5 (4)
# 									    									</img></div>
# <div class="participants">참여 멤버 31</div>
# </a>
# </div>
# </li>
# <li class="swiper-slide">
# <div>
# <p class="btn_wish have_click_event" data-id="1466"><img alt="찜하기" src="https://app-cdn.enfit.net/img/class/icon_heart_0.png"/></p>
# <a href="/class/classDetail/1466">
# <div class="product_img_wrap"><div class="product_img" style="background-image: url('https://app-cdn.enfit.net/uploads/photo_800/n9fphUNvk6mVyQqL.jpg?width=500&amp;height=500');"></div></div>
# </a>
# <a class="product_info" href="/class/classDetail/1466">
# <span>영상편집 · 그린필드</span>
# <h2>아무것도 몰라도 영상을 쉽게 만드는 파워디렉터 영상편집 클래스</h2>
# <div class="price_info">
# <b><span>월</span>29,000원</b>
# <span class="percent">63.2% 할인</span>
# </div>
# <div class="product_star">
# <img alt="1점 별 아이콘" src="https://app-cdn.enfit.net/img/class/icon_star_1.png"> 4.8 (6)
# 									    									</img></div>
# <div class="participants">참여 멤버 18</div>
# </a>
# </div>
# </li>
# <li class="swiper-slide">
# <div>
# <p class="btn_wish have_click_event" data-id="1241"><img alt="찜하기" src="https://app-cdn.enfit.net/img/class/icon_heart_2.png"/></p>
# <a href="/class/classDetail/1241">
# <div class="product_img_wrap"><div class="product_img" style="background-image: url('https://app-cdn.enfit.net/uploads/photo_800/9x6G3fqSnTfrRDCY.jpg?width=500&amp;height=500');"></div></div>
# </a>
# <a class="product_info" href="/class/classDetail/1241">
# <span>음악 · 추월</span>
# <h2>목아픔 걱정NO! 쉽고 빠르게 노래 실력을 늘려보자!</h2>
# <div class="price_info">
# <b><span>월</span>33,000원</b>
# <span class="percent">61% 할인</span>
# </div>
# <div class="product_star">
# <img alt="1점 별 아이콘" src="https://app-cdn.enfit.net/img/class/icon_star_1.png"> 4.7 (13)
# 									    									</img></div>
# <div class="participants">참여 멤버 65</div>
# </a>
# </div>
# </li>
# <li class="swiper-slide">
# <div>
# <p class="btn_wish have_click_event" data-id="2208"><img alt="찜하기" src="https://app-cdn.enfit.net/img/class/icon_heart_2.png"/></p>
# <a href="/class/classDetail/2208">
# <div class="product_img_wrap"><div class="product_img" style="background-image: url('https://app-cdn.enfit.net/uploads/photo_800/WSu8Xy19D33uRrHX.jpg?width=500&amp;height=500');"></div></div>
# </a>
# <a class="product_info" href="/class/classDetail/2208">
# <span>면접 · 백용식 소장 (조나단 연구소)</span>
# <h2>면접 전문가가 알려주는 꼭 합격하는 면접 비결</h2>
# <div class="price_info">
# <b><span>월</span>35,000원</b>
# <span class="percent">61% 할인</span>
# </div>
# <div class="product_star">
# <img alt="1점 별 아이콘" src="https://app-cdn.enfit.net/img/class/icon_star_1.png"> 5 (1)
# 									    									</img></div>
# <div class="participants">참여 멤버 7</div>
# </a>
# </div>
# </li>
# <li class="swiper-slide">
# <div>
# <p class="btn_wish have_click_event" data-id="1426"><img alt="찜하기" src="https://app-cdn.enfit.net/img/class/icon_heart_2.png"/></p>
# <a href="/class/classDetail/1426">
# <div class="product_img_wrap"><div class="product_img" style="background-image: url('https://app-cdn.enfit.net/uploads/photo_800/PpXTIRFHiBe2hVPZ.jpg?width=500&amp;height=500');"></div></div>
# </a>
# <a class="product_info" href="/class/classDetail/1426">
# <span>다이어트 · 종마</span>
# <h2>바디라인 탄력을 잡아주는 슬림탄탄 다이어트</h2>
# <div class="price_info">
# <b><span>월</span>33,000원</b>
# <span class="percent">63% 할인</span>
# </div>
# <div class="product_star">
# </div>
# <div class="participants">참여 멤버 19</div>
# </a>
# </div>
# </li>
# <li class="swiper-slide">
# <div>
# <p class="btn_wish have_click_event" data-id="2147"><img alt="찜하기" src="https://app-cdn.enfit.net/img/class/icon_heart_2.png"/></p>
# <a href="/class/classDetail/2147">
# <div class="product_img_wrap"><div class="product_img" style="background-image: url('https://app-cdn.enfit.net/uploads/photo_800/gMEZ9J4wU4iwpKaJ.jpg?width=500&amp;height=500');"></div></div>
# </a>
# <a class="product_info" href="/class/classDetail/2147">
# <span>말하기 · 민호우쌤</span>
# <h2>자신있게 영어로 소통하는 사람되는 국민영어법</h2>
# <div class="price_info">
# <b><span>월</span>29,000원</b>
# <span class="percent">67% 할인</span>
# </div>
# <div class="product_star">
# <img alt="1점 별 아이콘" src="https://app-cdn.enfit.net/img/class/icon_star_1.png"> 4.9 (180)
# 									    									</img></div>
# <div class="participants">참여 멤버 4,276</div>
# </a>
# </div>
# </li>
# <li class="swiper-slide">
# <div>
# <p class="btn_wish have_click_event" data-id="1403"><img alt="찜하기" src="https://app-cdn.enfit.net/img/class/icon_heart_2.png"/></p>
# <a href="/class/classDetail/1403">
# <div class="product_img_wrap"><div class="product_img" style="background-image: url('https://app-cdn.enfit.net/uploads/photo_800/HBWP466Esu52SBuq.jpeg?width=500&amp;height=500');"></div></div>
# </a>
# <a class="product_info" href="/class/classDetail/1403">
# <span>드로잉 · 단하빛</span>
# <h2>반짝이는 선물, 나만의 주얼리디자인! 색연필 일러스트 클래스</h2>
# <div class="price_info">
# <b><span>월</span>35,900원</b>
# <span class="percent">59.6% 할인</span>
# </div>
# <div class="product_star">
# <img alt="1점 별 아이콘" src="https://app-cdn.enfit.net/img/class/icon_star_1.png"> 5 (2)
# 									    									</img></div>
# <div class="participants">참여 멤버 26</div>
# </a>
# </div>
# </li>
# <li class="swiper-slide">
# <div>
# <p class="btn_wish have_click_event" data-id="1216"><img alt="찜하기" src="https://app-cdn.enfit.net/img/class/icon_heart_2.png"/></p>
# <a href="/class/classDetail/1216">
# <div class="product_img_wrap"><div class="product_img" style="background-image: url('https://app-cdn.enfit.net/uploads/photo_800/ocupoDWIL7cqlTDs.jpg?width=500&amp;height=500');"></div></div>
# </a>
# <a class="product_info" href="/class/classDetail/1216">
# <span>다이어트 · 길코치</span>
# <h2>집에서 배우는 킥복싱 완전 기초 4주 완성 클래스</h2>
# <div class="price_info">
# <b><span>월</span>29,900원</b>
# <span class="percent">66.4% 할인</span>
# </div>
# <div class="product_star">
# <img alt="1점 별 아이콘" src="https://app-cdn.enfit.net/img/class/icon_star_1.png"> 5 (17)
# 									    									</img></div>
# <div class="participants">참여 멤버 52</div>
# </a>
# </div>
# </li>
# <li class="swiper-slide">
# <div>
# <p class="btn_wish have_click_event" data-id="3315"><img alt="찜하기" src="https://app-cdn.enfit.net/img/class/icon_heart_0.png"/></p>
# <a href="/class/classDetail/3315">
# <div class="product_img_wrap"><div class="product_img" style="background-image: url('https://app-cdn.enfit.net/uploads/photo_800/Ziqz2BL6xVqv2P8E.png?width=500&amp;height=500');"></div></div>
# </a>
# <a class="product_info" href="/class/classDetail/3315">
# <span>외국어 · 오픽강사강보경</span>
# <h2>씨리얼 오픽 이슈주제</h2>
# <div class="price_info">
# <b><span>월</span>40,000원</b>
# <span class="percent">60% 할인</span>
# </div>
# <div class="product_star">
# </div>
# </a>
# </div>
# </li>
# <li class="swiper-slide">
# <div>
# <p class="btn_wish have_click_event" data-id="1352"><img alt="찜하기" src="https://app-cdn.enfit.net/img/class/icon_heart_2.png"/></p>
# <a href="/class/classDetail/1352">
# <div class="product_img_wrap"><div class="product_img" style="background-image: url('https://app-cdn.enfit.net/uploads/photo_800/aTZnwseMZj3xnjbw.jpg?width=500&amp;height=500');"></div></div>
# </a>
# <a class="product_info" href="/class/classDetail/1352">
# <span>DIY · 문소소</span>
# <h2>반려동물 미니어처! 양모로 콕콕 찔러 만드는 니들펠트</h2>
# <div class="price_info">
# <b><span>월</span>38,000원</b>
# <span class="percent">57.3% 할인</span>
# </div>
# <div class="product_star">
# <img alt="1점 별 아이콘" src="https://app-cdn.enfit.net/img/class/icon_star_1.png"> 5 (7)
# 									    									</img></div>
# <div class="participants">참여 멤버 21</div>
# </a>
# </div>
# </li>
# <li class="swiper-slide">
# <div>
# <p class="btn_wish have_click_event" data-id="1598"><img alt="찜하기" src="https://app-cdn.enfit.net/img/class/icon_heart_2.png"/></p>
# <a href="/class/classDetail/1598">
# <div class="product_img_wrap"><div class="product_img" style="background-image: url('https://app-cdn.enfit.net/uploads/photo_800/MjJMTjW092jvtsBd.jpg?width=500&amp;height=500');"></div></div>
# </a>
# <a class="product_info" href="/class/classDetail/1598">
# <span>드로잉 · 장아뜰리에</span>
# <h2>누구나 쉽게 연필 하나로 인물화 그리기</h2>
# <div class="price_info">
# <b><span>월</span>33,000원</b>
# <span class="percent">66% 할인</span>
# </div>
# <div class="product_star">
# <img alt="1점 별 아이콘" src="https://app-cdn.enfit.net/img/class/icon_star_1.png"> 4.8 (17)
# 									    									</img></div>
# <div class="participants">참여 멤버 56</div>
# </a>
# </div>
# </li>
# <li class="swiper-slide">
# <div>
# <p class="btn_wish have_click_event" data-id="1600"><img alt="찜하기" src="https://app-cdn.enfit.net/img/class/icon_heart_2.png"/></p>
# <a href="/class/classDetail/1600">
# <div class="product_img_wrap"><div class="product_img" style="background-image: url('https://app-cdn.enfit.net/uploads/photo_800/5WiW4Ol1LZ0d99RN.jpg?width=500&amp;height=500');"></div></div>
# </a>
# <a class="product_info" href="/class/classDetail/1600">
# <span>드로잉 · 솔생님</span>
# <h2>누구나 따라하고 싶은 디지털 라인드로잉&amp;캐리커쳐 드로잉'</h2>
# <div class="price_info">
# <b><span>월</span>35,000원</b>
# <span class="percent">60.6% 할인</span>
# </div>
# <div class="product_star">
# <img alt="1점 별 아이콘" src="https://app-cdn.enfit.net/img/class/icon_star_1.png"> 5 (4)
# 									    									</img></div>
# <div class="participants">참여 멤버 58</div>
# </a>
# </div>
# </li>
# <li class="swiper-slide">
# <div>
# <p class="btn_wish have_click_event" data-id="1147"><img alt="찜하기" src="https://app-cdn.enfit.net/img/class/icon_heart_2.png"/></p>
# <a href="/class/classDetail/1147">
# <div class="product_img_wrap"><div class="product_img" style="background-image: url('https://app-cdn.enfit.net/uploads/photo_800/TtQICxbQF8nrdjXr.jpeg?width=500&amp;height=500');"></div></div>
# </a>
# <a class="product_info" href="/class/classDetail/1147">
# <span>실무 · 엑셀능력자</span>
# <h2>[남들보다 2배 빠른 초고속 승진] 실무에서 인정받는 엑셀강의</h2>
# <div class="price_info">
# <b><span>월</span>29,000원</b>
# <span class="percent">57.9% 할인</span>
# </div>
# <div class="product_star">
# <img alt="1점 별 아이콘" src="https://app-cdn.enfit.net/img/class/icon_star_1.png"> 4.9 (34)
# 									    									</img></div>
# <div class="participants">참여 멤버 213</div>
# </a>
# </div>
# </li>
# <li class="swiper-slide">
# <div>
# <p class="btn_wish have_click_event" data-id="2302"><img alt="찜하기" src="https://app-cdn.enfit.net/img/class/icon_heart_0.png"/></p>
# <a href="/class/classDetail/2302">
# <div class="product_img_wrap"><div class="product_img" style="background-image: url('https://app-cdn.enfit.net/uploads/photo_800/ibspOmfQVRBC8hZd.jpeg?width=500&amp;height=500');"></div></div>
# </a>
# <a class="product_info" href="/class/classDetail/2302">
# <span>요리 · 리파</span>
# <h2>쉽게 배우는 분위기 있는 프랑스 가정식 클래스</h2>
# <div class="price_info">
# <b><span>월</span>30,000원</b>
# <span class="percent">62% 할인</span>
# </div>
# <div class="product_star">
# </div>
# <div class="participants">참여 멤버 3</div>
# </a>
# </div>
# </li>
# <li class="swiper-slide">
# <div>
# <p class="btn_wish have_click_event" data-id="1187"><img alt="찜하기" src="https://app-cdn.enfit.net/img/class/icon_heart_2.png"/></p>
# <a href="/class/classDetail/1187">
# <div class="product_img_wrap"><div class="product_img" style="background-image: url('https://app-cdn.enfit.net/uploads/photo_800/kzy3cndTlWuiLC6O.jpg?width=500&amp;height=500');"></div></div>
# </a>
# <a class="product_info" href="/class/classDetail/1187">
# <span>습관만들기 · 비비안</span>
# <h2>책 읽기, 함께하면 두렵지 않아! 한 달에 한 권 끝내기</h2>
# <div class="price_info">
# <b><span>월</span>32,900원</b>
# <span class="percent">58% 할인</span>
# </div>
# <div class="product_star">
# <img alt="1점 별 아이콘" src="https://app-cdn.enfit.net/img/class/icon_star_1.png"> 5 (5)
# 									    									</img></div>
# <div class="participants">참여 멤버 21</div>
# </a>
# </div>
# </li>
# <li class="swiper-slide">
# <div>
# <p class="btn_wish have_click_event" data-id="2801"><img alt="찜하기" src="https://app-cdn.enfit.net/img/class/icon_heart_0.png"/></p>
# <a href="/class/classDetail/2801">
# <div class="product_img_wrap"><div class="product_img" style="background-image: url('https://app-cdn.enfit.net/uploads/photo_800/lELpHxNfVX8b8BoF.jpg?width=500&amp;height=500');"></div></div>
# </a>
# <a class="product_info" href="/class/classDetail/2801">
# <span>라이프스타일 · 행복을 노래하는 사람</span>
# <h2>고래도 춤추게 하는 칭찬 에너지! 인생이 바뀝니다.</h2>
# <div class="price_info">
# <b><span>월</span>9,900원</b>
# <span class="percent">87% 할인</span>
# </div>
# <div class="product_star">
# </div>
# <div class="participants">참여 멤버 2</div>
# </a>
# </div>
# </li>
# <li class="swiper-slide">
# <div>
# ...
# 					});
# 				});
#
# 				var friend_update = database.ref('friend/');
# 				friend_update.on('value', function(snapshot) {
# 					var _data = snapshot.val();
#
# 					try {
# 						follwer_list_reload(_data.following);
# 					} catch(err) {
# 					}
# 				});
#
# 			}
#         } catch (err) {
#
# 		}
#     }
# </script>
# <!-- 카카오톡 플러스친구 -->
# <script src="//developers.kakao.com/sdk/js/kakao.min.js"></script>
# <script>
#     //<![CDATA[
#     Kakao.init('e1d49b55459efb99d8d231c4536e8923');
#
#     function plusFriendChat() {
#         if (mobileIF.ModooiOS()) {
#             webkit.messageHandlers.kakaoFriendHandler.postMessage('kakao');
#         } else if (mobileIF.ModooAnd()) {
#             android.modooContact();
#         } else {
#             Kakao.PlusFriend.chat({
#                 plusFriendId: '_sqfxdxl'
#             });
#         }
#     }
#     //]]>
#
#     // 카톡 공유하기
#     function shareKatalk(targetUrl, title, photoUrl, content) {
#         if (typeof targetUrl == "undefined" || targetUrl == '') {
#             targetUrl = location.href;
#         }
#
#         if (mobileIF.ModooiOS()) {
#             var param = {
#                 "url": targetUrl,
#                 "photoUrl": photoUrl,
#                 "title": title
#             };
#             webkit.messageHandlers.shareHandler.postMessage(param);
#         } else if (mobileIF.ModooAnd()) {
#             window.android.shareKakao(title, targetUrl);
#         } else {
#             if (typeof content == "undefined") {
#
#                 Kakao.Link.sendScrap({
#                     requestUrl: targetUrl
#                 });
#
#             } else {
#
#                 var _url = targetUrl;
#
#                 if(_url.indexOf('classtok.net') >= 0) {
#                     _url = _url.replace("https://www.classtok.net/", "");
#                 }
#
#                 if(_url.indexOf('classtok.net') >= 0) {
#                     _url = _url.replace("https://www.classtok.net/", "");
#                 }
#
#                 Kakao.Link.sendScrap({
#                     requestUrl: targetUrl,
#                     templateId: 17025,
#                     templateArgs: {
#                         title: title,
#                         content: content,
#                         image: photoUrl,
#                         url: _url,
#                         link: _url,
#                     }
#                 });
#             }
#         }
#     }
# </script>
# <script type="text/javascript">
#     // 모바일 에이전트 구분
#     var mobileIF = {
#         Android: function() {
#             return navigator.userAgent.match(/Android/i) == null ? false : true;
#         },
#         BlackBerry: function() {
#             return navigator.userAgent.match(/BlackBerry/i) == null ? false : true;
#         },
#         IOS: function() {
#             return navigator.userAgent.match(/iPhone|iPad|iPod/i) == null ? false : true;
#         },
#         Opera: function() {
#             return navigator.userAgent.match(/Opera Mini/i) == null ? false : true;
#         },
#         Windows: function() {
#             return navigator.userAgent.match(/IEMobile/i) == null ? false : true;
#         },
#         Kakao: function() {
#             return navigator.userAgent.match(/KAKAOTALK/i) == null ? false : true;
#         },
#         Chrome: function() {
#             return navigator.userAgent.match(/Chrome/i) == null ? false : true;
#         },
#         Safari: function() {
#             return navigator.userAgent.match(/Safari/i) == null ? false : true;
#         },
#         ModooiOS: function() {
#             return navigator.userAgent.match(/Modoo_ios/i) == null ? false : true;
#         },
#         ModooAnd: function() {
#             return navigator.userAgent.match(/Modoo_and/i) == null ? false : true;
#         },
#         Modooclass: function() {
#             return navigator.userAgent.match(/Modooclass/i) == null ? false : true;
#         },
#         any: function() {
#             return (mobileIF.Android() || mobileIF.BlackBerry() || mobileIF.IOS() || mobileIF.Opera() || mobileIF.Windows());
#         },
#         mobile: function() {
#             return (mobileIF.Android() || mobileIF.BlackBerry() || mobileIF.IOS() || mobileIF.Opera());
#         },
#         ModooClassApp: function() {
#             return (mobileIF.ModooiOS() || mobileIF.ModooAnd());
#         },
#         isMobileEvent: function() {
#             if (!mobileIF.ModooClassApp()) {
#                 document.getElementsByTagName('footer')[0].style.display = 'block';
#                 // document.documentElement.style.height = '100vh';
#                 // document.body.style.height = '100vh';
#                 var contentEl = document.getElementsByClassName('content')[0];
#                 if(contentEl) {
#                     contentEl.style.minHeight = '100vh';
#                 }
#                 // document.body.style.paddingBottom = 10 + 'px';
#             }
#         }
#     };
#
#     iosWithManagerNavHandler();
#
#     function iosWithManagerNavHandler() {
#         var managerNav = document.querySelector('.manager__list-nav');
#         if (mobileIF.ModooiOS() && managerNav) {
#             if(document.getElementsByClassName('calculate-nav').length > 0) {
#                 document.getElementsByClassName('calculate-nav')[0].style.display = 'none';
#                 document.querySelectorAll('.manager__list-nav .item-nav').forEach(function(item) {
#                     item.style.width = 'calc(100% / 4)';
#                 })
#             }
#         }
#     }
#
#     mobileIF.isMobileEvent();
#
#     function isMobilePrdDetailEvent() {
#         document.documentElement.style.height = 'auto';
#         document.body.style.height = 'auto';
#         if (mobileIF.ModooClassApp()) {
#             document.body.style.paddingBottom = 100 + 'px';
#         } else {
#             if (document.getElementsByClassName('btns-class').length > 0) {
#                 document.body.style.paddingBottom = document.getElementsByClassName('btns-class')[0].clientHeight + 10 + 'px';
#             }
#         }
#     }
#
#     $(function() {
#         if (mobileIF.ModooiOS() || mobileIF.ModooAnd()) {
#             // $('.btn-katalk-chat').hide();
#         }
#
#     });
#
#     function mobileInterface(type, direction, url, message, callback) {
#         // var interfaceList = {'iOS', 'Android', 'Web', 'Kakao', 'Mobile', 'Web'};
#         // switch (type) {
#         //   case 'iOS':
#
#         //     break;
#
#         //   default:
#         //     break;
#         // }
#     }
#
#     // back, scheme, into class
#
#     function loggingToApp(type, param, message) {
#         // ex) profile, done
#         // ex) kakao, done, param
#
#         //'url' : 'http://sdasdsa'
#         // reffrer : 'http://sdasdsa'
#         // id : classid, EtcId
#
#         // type: changeGroupHandler
#         // param: close
#         // mesage: done
#         // alert('type: '+type);
#         // alert('param: '+param);
#         // alert('message: '+message);
#     }
#
#     var deviceBackToHandler = {
#         LayerOff: function() {
#             // alert('Layer off');
#
#             try {
#                 deviceBackToHandlerLayerOff();
#                 return true;
#             } catch (error) {
#                 return true;
#             }
#         }
#     };
#
#
#
#     // 뒤로가기
#     $('.btn-back').on('click', function() {
#         // console.log('document.referrer: ', document.referrer);
#         // console.log('window.location.origin: ', window.location.origin);
#         // return;
#         if (mobileIF.ModooiOS()) {
#             document.referrer ? window.history.back() : webkit.messageHandlers.changeGroupHandler.postMessage('close');
#
#             // alert(document.referrer);
#
#             // if(document.referrer) {
#             //   window.history.back();
#             //   alert('back');
#             // } else {
#             //   webkit.messageHandlers.changeGroupHandler.postMessage('close');
#             //   alert('close');
#             // }
#
#             //logging
#             // webkit.messageHandlers.loggingHandler.postMessage('log');
#
#
#         } else if (mobileIF.ModooAnd()) {
#             document.referrer ? window.history.back() : window.android.exit();
#         } else {
#
#             window.history.back();
#         }
#
#     });
#
#     // 모두의클래스 메세지 연결 (고객센터)
#     function chatOpen(_room_id) {
#         if (mobileIF.ModooiOS()) {
#             webkit.messageHandlers.goToChatDetail.postMessage(_room_id);
#         } else if (mobileIF.ModooAnd()) {
#             window.android.goToChatDetail(_room_id);
#         } else {
#             location.href = 'https://www.classtok.net/class/chat/' + _room_id;
#         }
#     }
# </script>
# <script>
#     var winWidth = $(window).width(),
#         winHeight = $(window).height();
#
#
#     var _scrollPosition = $(window).scrollTop();
#
#     $(function() {
#
#         $(window).on('resize', function() {
#             winWidth = $(window).width(),
#                 winHeight = $(window).height();
#         });
#
#         // HEADER : 인기검색어 올라가는 효과
#         var ticker = function() {
#             setTimeout(function() {
#                 $('#ticker li').first().animate({
#                     marginTop: '-20px'
#                 }, 400, function() {
#                     $(this).detach().appendTo('ul#ticker').removeAttr('style');
#                 });
#                 ticker();
#             }, 3000);
#         };
#         ticker();
#
#         // HEADER : 인기검색어 박스 보이게
#         $('.search-term').hover(function() {
#             $('.search-term-box').addClass('on');
#         });
#
#         $('.search-term-box').mouseleave(function() {
#             $('.search-term-box').removeClass('on');
#         });
#
#         // $('.global-header__search-term').hover(function() {
#         //     $('.global-header__search-term-rank-box').addClass('active');
#         // });
#
#         // $('.global-header__search-term-rank-box').mouseleave(function() {
#         //     $('.global-header__search-term-rank-box').removeClass('active');
#         // });
#
#
#         // HEADER : 사이드 메뉴 햄버거 버튼 클릭 이벤트
#         $('#snb-btn').on('click', function() {
#             $('.side-content-wrap').addClass('on');
#             $('.blackBg').css('display', 'block');
#             $('body').css('overflow', 'hidden');
#         });
#
#         // HEADER : 사이드 메뉴 닫기 버튼
#         $('.btn-close').on('click', function() {
#             $('.side-content-wrap').removeClass('on');
#             $('body').css('overflow', 'auto');
#         });
#
#         // main dropdown menu 영역 외 클릭시 hide 처리
#         $('html').on('click', function(e) {
#             if (!$(e.target).is('.my-gym-nav-btn button')) {
#                 $('.my-gym-nav').hide();
#                 $('.my-gym-nav').siblings('button').removeClass('active');
#             }
#         });
#
#         // footer 사업자 정보
#         $('.mot_company_info').on('click', function() {
#             $('.mot_company_info_inner').slideToggle();
#             $(this).toggleClass('open');
#         });
#
#         moveTop('#moveTop');
#
#         dropDownMenuToggle('.my-gym-nav');
#
#     });
#
#     //moveTop
#     function moveTop(elem) {
#         var elem = $(elem);
#         elem.on('click', function() {
#             $('html, body').animate({
#                 scrollTop: 0
#             }, 'fast');
#         });
#     };
#
#     // dropdown-menu toggle
#     function dropDownMenuToggle(elem) {
#         $(elem + '-btn').on('click', function(e) {
#             $(this).children('button').toggleClass('active');
#             $(this).children(elem).toggle();
#         });
#     };
#
#     // 랜덤 칼라, 사이드 메뉴 태그 배경색
#     function randomColor() {
#         var randomColor = '#' + ('000000' + Math.floor(Math.random() * 16777215).toString(16)).slice(-6);
#         return randomColor;
#     }
#
#     function moveProfilePageOld() {
#         // if (mobileIF.ModooiOS()) {
#         //     webkit.messageHandlers.profileHandler.postMessage('profile');
#         // } else if (mobileIF.ModooAnd()) {
#         //     window.android.gotoprofile();
#         // } else {
#             location.href = "/class/user/mypage";
#         // }
#
#         // window.history.back();
#     }
#
#     function moveProfilePage(closeFlag) {
#         try {
#             agentStr=navigator.userAgent.split('Modoo_')[1];
#             appVersion = agentStr.replace(/[^0-9]/g,"");
#         } catch (error) {
#             // desktop
#             appVersion = 0;
#         }
#
#         var userId = 0;
#         if('' == '') {
#             location.href = "/class/user/mypage";
#             return;
#         } else {
#             userId = "";
#         }
#
#         if (parseInt(appVersion) >= 190) {
#             try {
#                 if(closeFlag) {
#                     if (mobileIF.ModooiOS()) {
#                         webkit.messageHandlers.webViewExit.postMessage('exit');
#                     } else if (mobileIF.ModooAnd()) {
#                         window.android.webViewExit();
#                     } else {
#                         location.href = "/class/user/mypage";
#                     }
#                 } else {
#                     if (mobileIF.ModooiOS()) {
#                         webkit.messageHandlers.goToProfile.postMessage(userId);
#                     } else if (mobileIF.ModooAnd()) {
#                         window.android.goToProfile(userId);
#                     } else {
#                         location.href = "/class/user/mypage";
#                     }
#                 }
#
#
#             } catch (error) {
#                 console.log(error);
#                 location.href = "/class/user/mypage";
#             }
#         } else {
#             location.href = "/class/user/mypage";
#         }
#     }
#
#     function moveMcHome() {
#         if (mobileIF.ModooiOS()) {
#             webkit.messageHandlers.homeHandler.postMessage('home');
#         } else if (mobileIF.ModooAnd()) {
#             window.android.gotohome();
#         } else {
#             location.href = "/";
#         }
#     }
#
#     function closeWebview() {
#         if (mobileIF.ModooiOS()) {
#             webkit.messageHandlers.changeGroupHandler.postMessage('close');
#         } else if (mobileIF.ModooAnd()) {
#             window.android.exit();
#         } else {
#             location.href = "/class/mainclass";
#         }
#     }
#
#     function historyBackHandler() {
#         if (mobileIF.ModooiOS()) {
#             document.referrer ? window.history.back() : webkit.messageHandlers.changeGroupHandler.postMessage('close');
#         } else if (mobileIF.ModooAnd()) {
#             document.referrer ? window.history.back() : window.android.exit();
#         } else {
#             window.history.back();
#         }
#     }
#
#     function addEventListenerByClassHandler(cls, event, fn) {
# 		var target = document.getElementsByClassName(cls);
# 		if(!target) return;
#
#         var targetLength = target.length;
# 		for(var i = 0; i < targetLength; i++) {
# 			target[i].addEventListener(event, fn, false);
# 		}
#     }
#
#     addEventListenerByClassHandler('header__back-button', 'click', historyBackHandler);
#     addEventListenerByClassHandler('header__home-button', 'click', moveMcHome);
#
# </script>
# <script src="//cdnjs.cloudflare.com/ajax/libs/socket.io/2.2.0/socket.io.js"></script>
# <script>
#     (function(){
#         var doc = document.documentElement;
#         var w = window;
#
#         var prevScroll = w.scrollY || doc.scrollTop;
#         var curScroll;
#         var direction = 0;
#         var prevDirection = 0;
#
#         var header = document.getElementById('header');
#         if(!header) return;
#
#         var toggleHeader = function(direction, curScroll) {
#             if (direction === 2 && curScroll > header.offsetHeight) {
#                 header.classList.add('hide');
#                 prevDirection = direction;
#             } else if (direction === 1) {
#                 header.classList.remove('hide');
#                 prevDirection = direction;
#             }
#         };
#
#         var checkScroll = function() {
#             curScroll = w.scrollY || doc.scrollTop;
#
#             if (curScroll > prevScroll) {
#                 direction = 2;
#             } else if (curScroll < prevScroll) {
#                 direction = 1;
#             }
#
#             if (direction !== prevDirection) {
#                 toggleHeader(direction, curScroll);
#             }
#
#             prevScroll = curScroll;
#         };
#
#         window.addEventListener('scroll', checkScroll);
#     })();
# </script>
# </body>

# %%
elements = soup.select('body > div.main_wrap > div > div > ul > div > li > div > a.product_info')
len(elements)
# Out:
# 347

# %%
links = []
for i in range(len(elements)):
    links.append('https://classtok.net' + str(elements[i]).replace('<a class="product_info" href="', '').split('">\n<span>')[0])
len(links)
# Out:
# 347

# %%
#site, title, category_2, teacher, price, discount, likes, link

# %%
onetime = []
datas = []

for element in elements:
    
    site = '클래스톡'
    try:
        likes = element.select_one('.product_star').text.split()[0]
    except:
        likes = ''
    
    datas.append({
        "site" : site,
        "title" : element.select_one('h2').text,
        "category_2" : element.select_one('span').text.split(' · ')[0],
        "teacher" : element.select_one('span').text.split(' · ')[1],
        "price" : element.select_one('.price_info').text.split('\n')[1],
        "discount" : element.select_one('.price_info').text.split('\n')[2].replace(' 할인',''),
        "likes" : likes,
        "link" : 'https://www.classtok.net' + element.get('href'),
    })
    onetime.append(datas)
classtok_df = pd.DataFrame(datas)
classtok_df.tail()
# Out:
#      site                            title category_2 teacher     price  \
# 342  클래스톡  유튜버 치하키의 핸드폰으로 영상 만들기 : 블로 VLLO       영상편집     치하키  월26,900원
# 343  클래스톡       [new]워너비 몸매를 만드는 다이어트 필라테스       필라테스    윤주코치  월29,000원
# 344  클래스톡              반려견 베이커리 배우기 초급 클래스         요리   빵굽는하루  월39,500원
# 345  클래스톡               안녕, 기타 : ) 통기타 클래스        통기타     박상규  월30,000원
# 346  클래스톡          연예인들의 말하기 선생님에게 배우는 스피치        스피치    민호우쌤  월29,000원
#
#     discount likes                                             link
# 342    65.9%   4.9  https://www.classtok.net/class/classDetail/1349
# 343      67%     5  https://www.classtok.net/class/classDetail/2580
# 344    60.1%     5  https://www.classtok.net/class/classDetail/1301
# 345      62%     5  https://www.classtok.net/class/classDetail/1736
# 346      63%   4.9  https://www.classtok.net/class/classDetail/2222

# %%
classtok_df = classtok_df.append(onetime)
print('time: ', round((time.time() - start)/60, 1), '분', sep='')
print('\n')
# Out:
# time: 0.1분

# %%
classtok_df.to_csv(f'./classtok_{datetime.datetime.now().strftime("%y%m%d%H%M%S")}.csv', encoding='utf-8')

# %%
print('전체')
print('time: ', round((time.time() - start)/60, 1), '분', sep='')
print('\n')
print('total: ', len(classtok_df))
# Out:
# 전체
# time: 0.2분
#
#
# total: 694
