# %% [markdown]
# ## 탈잉
# ### 카테고리 :취미/공예
#
# - 총 125 페이지
# - 페이지 당 15개 클래스
# - likes,link,location,number,price,teacher,title
# - 'location'의 경우 타 사이트와의 비교 후 tile과 합칠 예정 `'[' + location + ']' + title`
#
# - 해당 카테고리 내에 있는 1873개(오후기준: 1875개) 클래스 중 모두 크롤링 완료
# - 추가 내용: taling-test7.csv
#     - 'soldout'클래스 (soldout box 유무) 추가 수정예정
#     -  중간에 생겼다 사라지는 클래스의 경우 축적된 데이터로 어떻게 활용할 지 생각

# %% [markdown]
# #### 사이트 구조
# - 프레임워크: scrapy
#     - get 방식
#     - html : 정적페이지
#     - 반응형
#
# - 카테고리 분류
#     - 메인 카테고리
#     - 서브 카테고리    (질문: 서브 카테고리로 들어갔을 때 Url 규칙x, 메인->서브로의 연결)
#     - 클래스 페이지(상세페이지)
#
#
#     - spider.py -> __init__ (url 규칙성 {})  수정하는 파일
#     - start_urls -> page, cateMain
#
#     -위 방법이 안되면 클롤링한 데이터 모두 합산한 후 마지막에 카테고리 분류 할 지 고민중

# %%
import scrapy, requests, re 
from scrapy.http import TextResponse

import pandas as pd

# %%
# 프로젝트 생성

# %%
# !scrapy startproject tal_ing
# Out:
# New Scrapy project 'tal_ing', using template directory 'C:\Users\study\anaconda3\lib\site-packages\scrapy\templates\project', created in:
#     C:\Users\study\Desktop\crawling\tal_ing
#
# You can start your first spider with:
#     cd tal_ing
#     scrapy genspider example example.com

# %%
# link

# %%
req = requests.get("https://taling.me/Home/Search/?cateMain=22")
response = TextResponse(req.url, body=req.text, encoding="utf-8")
response
# Out:
# <200 https://taling.me/Home/Search/?cateMain=22>

# %%
# xpath 찾기 (page 1)

# %%
links = response.xpath('//*[@id="top-space"]/div/div/a/@href').extract()
len(links), links
# Out:
# (15,
#  ['/Talent/Detail/33374',
#   '/Talent/Detail/32152',
#   '/Talent/Detail/3750',
#   '/Talent/Detail/18571',
#   '/Talent/Detail/3281',
#   '/Talent/Detail/7060',
#   '/Talent/Detail/12005',
#   '/Talent/Detail/15043',
#   '/Talent/Detail/3309',
#   '/Talent/Detail/4109',
#   '/Talent/Detail/4617',
#   '/Talent/Detail/28671',
#   '/Talent/Detail/9057',
#   '/Talent/Detail/3922',
#   '/Talent/Detail/26028'])

# %%
links = list(map(response.urljoin, links))
links
# Out:
# ['https://taling.me/Talent/Detail/33374',
#  'https://taling.me/Talent/Detail/32152',
#  'https://taling.me/Talent/Detail/3750',
#  'https://taling.me/Talent/Detail/18571',
#  'https://taling.me/Talent/Detail/3281',
#  'https://taling.me/Talent/Detail/7060',
#  'https://taling.me/Talent/Detail/12005',
#  'https://taling.me/Talent/Detail/15043',
#  'https://taling.me/Talent/Detail/3309',
#  'https://taling.me/Talent/Detail/4109',
#  'https://taling.me/Talent/Detail/4617',
#  'https://taling.me/Talent/Detail/28671',
#  'https://taling.me/Talent/Detail/9057',
#  'https://taling.me/Talent/Detail/3922',
#  'https://taling.me/Talent/Detail/26028']

# %%
# 강좌정보 xpath

# %%
link = links[5]
req = requests.get(link)
response = TextResponse(req.url, body=req.text, encoding="utf-8")
response
# Out:
# <200 https://taling.me/Talent/Detail/7060>

# %%
# title, month(number of time), discount(x), price, category2, teacher, heart, likes, category1, link 
# 탈잉에서 category 분류는 페이지로 구분

# %%
title = response.xpath('//*[@id="wrap"]/div[2]/div[1]/section[1]/h1/text()')[0].extract()
teacher = response.xpath('//*[@id="wrap"]/div[2]/div[1]/section[1]/div/div[2]/em/text()')[0].extract()
number = response.xpath('//*[@id="wrap"]/div[2]/aside/div/p/span[2]/span/text()')[0].extract()
price = response.xpath('//*[@id="wrap"]/div[2]/div[3]/div/div[2]/p/span[2]/b/text()')[0].extract()
likes = response.xpath('//*[@id="wrap"]/div[2]/div[1]/section[1]/div/div[2]/span/i[2]/text()')[0].extract()
location = response.xpath('//*[@id="wrap"]/div[2]/div[3]/div/div[2]/div/p[2]/text()')[0].extract().strip()


title, teacher, number, price, likes, location
# Out:
# ('[오프라인] 아이패드로 하루만에 움직이는 이모티콘을 만들어봐용 ✨',
#  'nini 튜터',
#  '총 1회 3시간',
#  '75,000원 /',
#  '4.9',
#  '강남 부평 종로')

# %%
# items.py

# %%
# %%writefile tal_ing/tal_ing/items.py
import scrapy


class TalIngItem(scrapy.Item):
    title = scrapy.Field()
    teacher = scrapy.Field()
    number = scrapy.Field()
    price = scrapy.Field()
    likes = scrapy.Field()
    location = scrapy.Field()
    link = scrapy.Field()
# Out:
# Overwriting tal_ing/tal_ing/items.py

# %%
# spider.py

# %%
# %%writefile tal_ing/tal_ing/spiders/spider.py
import scrapy
from tal_ing.items import TalIngItem


class TalIngSpider(scrapy.Spider):
    name = "TalingHobby"
    allow_domain = ["taling.me"]
    pages = range(1, 125+1)
    start_urls = [f"https://taling.me/Home/Search/?page={page}&cateMain=22&cateSub=&region=&orderIdx=&query=&code=&org=&day=&time=&tType=&region=&regionMain=" for page in pages]
    
    def parse(self, response):
        links = response.xpath('//*[@id="top-space"]/div/div/a/@href').extract()
        links = list(map(response.urljoin, links))
        for link in links:
            yield scrapy.Request(link, callback=self.parse_content)
    
    def parse_content(self, response):
        item = TalIngItem()
        item["title"] = response.xpath('//*[@id="wrap"]/div[2]/div[1]/section[1]/h1/text()')[0].extract()
        item["teacher"] = response.xpath('//*[@id="wrap"]/div[2]/div[1]/section[1]/div/div[2]/em/text()')[0].extract()
        try:
            item["number"] = response.xpath('//*[@id="wrap"]/div[2]/aside/div/p/span[2]/span/text()')[0].extract()
        except:
            item["number"] = response.xpath('//*[@id="wrap"]/div[2]/div[3]/div/div[2]/p/span[2]/span/text()')[0].extract()
        item["price"] = response.xpath('//*[@id="wrap"]/div[2]/div[3]/div/div[2]/p/span[2]/b/text()')[0].extract()
        try:
            item["likes"] = response.xpath('//*[@id="wrap"]/div[2]/div[1]/section[1]/div/div[2]/span/i[2]/text()')[0].extract()
        except:
            item["likes"] = "(0)"
        item["location"] = response.xpath('//*[@id="wrap"]/div[2]/div[3]/div/div[2]/div/p[2]/text()')[0].extract().strip()
        item["link"] = response.url
        yield item
# Out:
# Overwriting tal_ing/tal_ing/spiders/spider.py

# %%
pages = range(1, 125+1)
start_urls = [f"https://taling.me/Home/Search/?page={page}&cateMain=22&cateSub=&region=&orderIdx=&query=&code=&org=&day=&time=&tType=&region=&regionMain=" for page in pages]
req = requests.get(start_urls[0])
response = TextResponse(req.url, body=req.text, encoding="utf-8")

links = response.xpath('//*[@id="top-space"]/div/div/a/@href').extract()
links = list(map(response.urljoin, links))
req = requests.get(links[1])
response = TextResponse(req.url, body=req.text, encoding="utf-8")

title = response.xpath('//*[@id="wrap"]/div[2]/div[1]/section[1]/h1/text()')[0].extract()
teacher = response.xpath('//*[@id="wrap"]/div[2]/div[1]/section[1]/div/div[2]/em/text()')[0].extract()
number = response.xpath('//*[@id="wrap"]/div[2]/aside/div/p/span[2]/span/text()')[0].extract()
price = response.xpath('//*[@id="wrap"]/div[2]/div[3]/div/div[2]/p/span[2]/b/text()')[0].extract()
likes = response.xpath('//*[@id="wrap"]/div[2]/div[1]/section[1]/div/div[2]/span/i[2]/text()')[0].extract() 
location = response.xpath('//*[@id="wrap"]/div[2]/div[3]/div/div[2]/div/p[2]/text()')[0].extract().strip()
link = response.url

title, teacher, number, price, likes, location, link
# Out:
# ('요즘 대세는 쥬브썸 플라워 스튜디오 :)',
#  '신지우 튜터',
#  '총 1회 2시간',
#  '40,000원 /',
#  '5.0',
#  '신촌홍대',
#  'https://taling.me/Talent/Detail/32152')

# %%
# %pwd
# Out:
# 'C:\\Users\\study\\Desktop\\crawling'

# %%
# %ls tal_ing
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 7DCE-F2C1
#
#  Directory of C:\Users\study\Desktop\crawling\tal_ing\tal_ing
#
# 2021-03-02  �삤�썑 07:11    <DIR>          .
# 2021-03-02  �삤�썑 07:11    <DIR>          ..
# 2021-02-23  �삤�썑 08:28                 0 __init__.py
# 2021-03-02  �삤�썑 07:11    <DIR>          __pycache__
# 2021-03-02  �삤�썑 06:48               258 items.py
# 2021-03-02  �삤�썑 06:48             3,648 middlewares.py
# 2021-03-02  �삤�썑 06:48               360 pipelines.py
# 2021-03-02  �삤�썑 06:48             3,065 settings.py
# 2021-03-02  �삤�썑 07:11    <DIR>          spiders
#                5 File(s)          7,331 bytes
#                4 Dir(s)  343,526,658,048 bytes free

# %%
# %%writefile run.sh
# cd C:\Users\study\Desktop\crawling\tal_ing
# scrapy crawl TalingHobby -o taling-test5.csv
# Out:
# Overwriting run.sh

# %%
# !ls
# Out:
# scrapy.cfg
# tal_ing

# %%
# %cd tal_ing/
# Out:
# C:\Users\study\Desktop\crawling\tal_ing

# %%
# !pwd
# Out:
# /c/Users/study/Desktop/crawling/tal_ing

# %%
# !/bin/bash run.sh         # 서버에서... 윈도우 부들부들
# Out:
# The system cannot find the path specified.

# %%
# !scrapy crawl TalingHobby -o taling-test5.csv -t csv # 터미널로 가세요 0_0 너는 윈도우에요.
# Out:
# ^C

# %%
pd.read_csv("tal_ing/taling-test7.csv")
# Out:
#      likes                                   link        location     number  \
# 0      4.9  https://taling.me/Talent/Detail/15128              강남   총 1회 2시간
# 1      5.0  https://taling.me/Talent/Detail/23609              강서   총 1회 2시간
# 2      5.0  https://taling.me/Talent/Detail/31172             왕십리   총 4회 4시간
# 3      5.0   https://taling.me/Talent/Detail/3503  강남 온라인 Live 논현   총 1회 2시간
# 4      5.0  https://taling.me/Talent/Detail/20164              구로   총 4회 4시간
# ...    ...                                    ...             ...        ...
# 1870   (0)  https://taling.me/Talent/Detail/13311            대구중앙   총 1회 2시간
# 1871   (0)   https://taling.me/Talent/Detail/8358          구월동 수원   총 1회 3시간
# 1872   (0)   https://taling.me/Talent/Detail/7426           서현 잠실  총 5회 10시간
# 1873   (0)  https://taling.me/Talent/Detail/25979            신촌홍대   총 1회 3시간
# 1874   (0)  https://taling.me/Talent/Detail/14610           부산부경대   총 1회 2시간
#
#            price     teacher  \
# 0      30,000원 /      박현준 튜터
# 1      78,000원 /     KIKO 튜터
# 2     150,000원 /  SCHOLAR 튜터
# 3      50,000원 /      남재현 튜터
# 4     150,000원 /      신성우 튜터
# ...          ...         ...
# 1870   20,000원 /      김미선 튜터
# 1871   84,000원 /      임은영 튜터
# 1872  120,000원 /      김혜진 튜터
# 1873   90,000원 /      장세미 튜터
# 1874   40,000원 /      공재현 튜터
#
#                                                   title
# 0                     [원데이] 나만의 느낌있는 드로잉으로, 나만의 드로잉 하기!
# 1                  샹들리에 케이크: 하루 배워 해마다 써먹기! (앙금+생크림 조합)
# 2      [연습생 출신/현직 탑라이너/작곡가] 자신에게 맞는 커리큘럼으로 개성과 실력을 동시에!
# 3     [강남 1위/90분 원데이] '최고의 장비' 분석을 통해 '고음' '발성 문제' 바...
# 4           (작곡클래스) 방구석 건반/작곡으로 끝장 보자!!   [구로디지털단지][신림]
# ...                                                 ...
# 1870       인스타사진 예쁘게 찍는 꿀팁/촬영/보정/ 필름카메라로 인생샷 남기기까지 단 하루
# 1871                [인천/원데이] 특별한 날 특별한 분께 드리는 플라워 앙금케이크
# 1872              (발손가능) 여행,영화의 특별한 순간들을 나만의 일러스트로 남기기!
# 1873                               레터링 케이크 만들기 실전반 클래스
# 1874                         [부산]2시간만에 나만의 음원제작해볼까요??^^
#
# [1875 rows x 7 columns]

# %%
pages = range(1, 125+1)
start_urls = [f"https://taling.me/Home/Search/?page={page}&cateMain=22&cateSub=&region=&orderIdx=&query=&code=&org=&day=&time=&tType=&region=&regionMain=" for page in pages]
start_urls[:10]
# Out:
# ['https://taling.me/Home/Search/?page=1&cateMain=22&cateSub=&region=&orderIdx=&query=&code=&org=&day=&time=&tType=&region=&regionMain=',
#  'https://taling.me/Home/Search/?page=2&cateMain=22&cateSub=&region=&orderIdx=&query=&code=&org=&day=&time=&tType=&region=&regionMain=',
#  'https://taling.me/Home/Search/?page=3&cateMain=22&cateSub=&region=&orderIdx=&query=&code=&org=&day=&time=&tType=&region=&regionMain=',
#  'https://taling.me/Home/Search/?page=4&cateMain=22&cateSub=&region=&orderIdx=&query=&code=&org=&day=&time=&tType=&region=&regionMain=',
#  'https://taling.me/Home/Search/?page=5&cateMain=22&cateSub=&region=&orderIdx=&query=&code=&org=&day=&time=&tType=&region=&regionMain=',
#  'https://taling.me/Home/Search/?page=6&cateMain=22&cateSub=&region=&orderIdx=&query=&code=&org=&day=&time=&tType=&region=&regionMain=',
#  'https://taling.me/Home/Search/?page=7&cateMain=22&cateSub=&region=&orderIdx=&query=&code=&org=&day=&time=&tType=&region=&regionMain=',
#  'https://taling.me/Home/Search/?page=8&cateMain=22&cateSub=&region=&orderIdx=&query=&code=&org=&day=&time=&tType=&region=&regionMain=',
#  'https://taling.me/Home/Search/?page=9&cateMain=22&cateSub=&region=&orderIdx=&query=&code=&org=&day=&time=&tType=&region=&regionMain=',
#  'https://taling.me/Home/Search/?page=10&cateMain=22&cateSub=&region=&orderIdx=&query=&code=&org=&day=&time=&tType=&region=&regionMain=']

# %%
response.text
# Out:
# '\r\n<!DOCTYPE html>\r\n<html>\r\n<head>\r\n\r\n    <title>요즘 대세는 쥬브썸 플라워 스튜디오 :) | 탈잉</title>\r\n    <meta property="og:title" content="요즘 대세는 쥬브썸 플라워 스튜디오 :) | 탈잉">\r\n    <meta property="og:image" content="http://s3.ap-northeast-2.amazonaws.com/taling.me/Content/Uploads/Cover/779685be6f63e4636ceeecec71cfbf076e27d746.png">\r\n    <meta property="og:site_name" content="탈잉">\r\n\r\n    <meta property="og:description" content="ㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡ\r\n\r\n&lt; juuvesome flower studio &gt;\r\n\r\nIt\'s HEELING TIME :)\r\n\r\n처음 꽃을 만져보시는 분들께서도 쉽게 다루실 수 있게 1:1 밀착 수업 진행합니다!\r\n\r\n꽃다발, 플라워 박스, 꽃바구니 중 택 1입니다!\r\n가격은 동일합니다 :)\r\n\r\nㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡ\r\n">\r\n    <meta name="description" content="ㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡ\r\n\r\n&lt; juuvesome flower studio &gt;\r\n\r\nIt\'s HEELING TIME :)\r\n\r\n처음 꽃을 만져보시는 분들께서도 쉽게 다루실 수 있게 1:1 밀착 수업 진행합니다!\r\n\r\n꽃다발, 플라워 박스, 꽃바구니 중 택 1입니다!\r\n가격은 동일합니다 :)\r\n\r\nㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡ\r\n">\r\n    <meta property="og:type" content="article">\r\n    <meta property="og:url" content="http://taling.me/Talent/Detail/32152">\r\n    <link rel="image_src" href="//s3.ap-northeast-2.amazonaws.com/taling.me/Content/Uploads/Cover/779685be6f63e4636ceeecec71cfbf076e27d746.png">\r\n\r\n    <meta http-equiv="Content-Type" content="text/html; charset=utf-8" />\r\n<meta http-equiv="X-UA-Compatible" content="IE=edge" />\r\n<meta name="viewport" content="width=device-width, initial-scale=1, maximum-scale=1">\r\n<meta name="description" content="매력 넘치는 능력자들에게 수업을 들어보세요. 베이킹부터 엑셀까지 다 있다!">\r\n<meta property="og:title" content="탈잉 - 세상의 모든 재능">\r\n<meta property="og:type" content="website" /> \r\n<meta property="og:url" content="https://taling.me/">\r\n<meta property="og:image" content="https://front-img.taling.me/Content/Images/ogimage2.png" />\r\n<meta property="og:description" content="매력 넘치는 능력자들에게 수업을 들어보세요. 베이킹부터 엑셀까지 다 있다!">\r\n<meta name="p:domain_verify" content="1dd028b45d9d85306bb74db3d9911bbb"/>\r\n<!--<meta name="apple-itunes-app" content="app-id=1153218962">-->\r\n\r\n<link rel="canonical" href="https://taling.me">\r\n<link rel="shortcut icon" href="https://front-img.taling.me/Content/app3/images/favicon.ico" />\r\n<link rel="apple-touch-icon" href="https://front-img.taling.me/Content/Images/mobicon.png"/>\r\n\r\n<script src="/Scripts/app3/jquery-1.12.4.min.js"></script>\r\n<script src="/Scripts/app3/lazysizes.min.js"></script>\r\n<script src="/Scripts/app3/jquery-ui.js"></script>\r\n<script>\r\n    !function(t,e,n,s,a,c,i,o,p){t.AppsFlyerSdkObject=a,t.AF=t.AF||function(){\r\n        (t.AF.q=t.AF.q||[]).push([Date.now()].concat(Array.prototype.slice.call(arguments)))},\r\n        t.AF.id=t.AF.id||i,t.AF.plugins={},o=e.createElement(n),p=e.getElementsByTagName(n)[0],o.async=1,\r\n        o.src="https://websdk.appsflyer.com?"+(c.length>0?"st="+c.split(",").sort().join(",")+"&":"")+(i.length>0?"af_id="+i:""),\r\n        p.parentNode.insertBefore(o,p)}(window,document,"script",0,"AF","banners",{banners: {key: "f36be0e5-9db5-458b-8432-0e7e11800acf"}});\r\n\r\n        AF(\'banners\', \'showBanner\', {additionalParams: {af_dp: \'taling%3A%2F%2Ftaling.me%2FTalent%2FDetail%2F32152\'}});\r\n    </script>\r\n<link rel="stylesheet" href="/Content/app3/css/common.css?ver=201204" media="all">\r\n<link rel="stylesheet" href="/Content/app3/css/notokr.css?ver=201204" media="all">\r\n<link rel="stylesheet" href="/Content/app3/css/jquery.mCustomScrollbar.css" media="all">\r\n<link type="text/css" rel="stylesheet" href="/Content/app3/css/header_pc.css?ver=201204" />\r\n<link type="text/css" rel="stylesheet" href="/Content/app3/css/footer_pc.css?ver=201204" />\r\n<link rel="stylesheet" href="/Content/app3/css/login/login_pc.css?ver=20090313" media="all">\r\n\r\n<script src="/Scripts/app3/header.js?ver=210224"></script>\r\n<script src="/Scripts/topbar.js"></script>\r\n<script src="/Scripts/app3/jquery.mCustomScrollbar.concat.min.js?ver=20081114"></script>\r\n\r\n<!--- pc,m ...

# %%
'[' + location + ']' + title
# Out:
# '[신촌홍대]요즘 대세는 쥬브썸 플라워 스튜디오 :)'

# %%
/html/body/div[21]/div/div[2]/div[4]/dl[1]/dd

# %%
from bs4 import BeautifulSoup
url = 'https://class101.net/products/HecSpAww7RHFuLUzqBjR'
req = requests.get(url)
soup = BeautifulSoup(req.text, 'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
# <html lang="ko"><head><meta charset="utf-8"/><title data-react-helmet="true">클래스101 | 센트보틀의 일상에 선물이 되는 향기 만들기</title><meta content="클래스101" data-react-helmet="true" name="name"/><meta data-react-helmet="true" name="author"/><meta content=" 클래스 소개영상&amp;gt;&amp;gt; 감성적이고 모던한 캔들을 만들어 보아요! 센트보틀은 감성적인 캔들, 트렌디 하고 모던한 캔들에 주목합니다. 캔들의 기초부터 차근차근 재료의 준비 부터 작품 제작까지 모두 알아볼 거예요! 이 클래스를 통해 캔들 제작과정의 즐거움을 느껴요! 동시에  캔들 재료의 올바른 이해와 캔들과 방향제류의 올바른 사용법도 알려드려요 . 왁스" data-react-helmet="true" name="description"/><meta content="향,조향,향기,향수,캔들,디퓨저,방향제,감성,모던,아로마,핸드메이드,공예,향초,초" data-react-helmet="true" property="keywords"/><meta content="클래스101" data-react-helmet="true" property="og:site_name"/><meta content="센트보틀의 일상에 선물이 되는 향기 만들기" data-react-helmet="true" property="og:title"/><meta content="https://class101.net/products/HecSpAww7RHFuLUzqBjR" data-react-helmet="true" property="og:url"/><meta content=" 클래스 소개영상&amp;gt;&amp;gt; 감성적이고 모던한 캔들을 만들어 보아요! 센트보틀은 감성적인 캔들, 트렌디 하고 모던한 캔들에 주목합니다. 캔들의 기초부터 차근차근 재료의 준비 부터 작품 제작까지 모두 알아볼 거예요! 이 클래스를 통해 캔들 제작과정의 즐거움을 느껴요! 동시에  캔들 재료의 올바른 이해와 캔들과 방향제류의 올바른 사용법도 알려드려요 . 왁스" data-react-helmet="true" property="og:description"/><meta content="https://cdn.class101.net/images/d0af9733-9097-488c-b750-2ad161bf88f5/1200x630" data-react-helmet="true" property="og:image"/><meta content="1200" data-react-helmet="true" property="og:image:width"/><meta content="630" data-react-helmet="true" property="og:image:height"/><meta content="https://cdn.class101.net/images/d0af9733-9097-488c-b750-2ad161bf88f5/1200x630" data-react-helmet="true" name="twitter:image"/><meta content="summary_large_image" data-react-helmet="true" name="twitter:card"/><meta data-react-helmet="true" name="twitter:creator"/><meta content="센트보틀의 일상에 선물이 되는 향기 만들기" data-react-helmet="true" name="twitter:title"/><meta content=" 클래스 소개영상&amp;gt;&amp;gt; 감성적이고 모던한 캔들을 만들어 보아요! 센트보틀은 감성적인 캔들, 트렌디 하고 모던한 캔들에 주목합니다. 캔들의 기초부터 차근차근 재료의 준비 부터 작품 제작까지 모두 알아볼 거예요! 이 클래스를 통해 캔들 제작과정의 즐거움을 느껴요! 동시에  캔들 재료의 올바른 이해와 캔들과 방향제류의 올바른 사용법도 알려드려요 . 왁스" data-react-helmet="true" name="twitter:description"/><meta content="Written By" data-react-helmet="true" name="twitter:label1"/><meta data-react-helmet="true" name="twitter:data1"/><meta content="web" data-react-helmet="true" name="environment"/><meta content="149966138967961" data-react-helmet="true" name="fb:app_id"/><link data-react-helmet="true" href="https://class101.net/products/HecSpAww7RHFuLUzqBjR" rel="canonical"/><script data-react-helmet="true" type="application/ld+json">{
#         "@context": "https://schema.org",
#         "@type": "Product",
#         "name": "센트보틀의 일상에 선물이 되는 향기 만들기",
#         "aggregateRating": {
#             "@type": "AggregateRating",
#             "ratingValue": 4.9,
#             "ratingCount": 640
#         }
#     }</script><meta content="IE=edge" http-equiv="X-UA-Compatible"/><meta content="width=device-width, height=device-height, initial-scale=1, minimum-scale=1, maximum-scale=1, user-scalable=no" name="viewport"/><meta content="149966138967961" property="fb:app_id"/><link href="/images/manifest.json" rel="manifest"/><link href="/images/favicon.ico" rel="shortcut icon"/><link href="/images/apple-touch-icon.png" rel="apple-touch-icon" sizes="180x180"/><link href="/images/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/><link href="/images/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/><link href="/images/favicon-48x48.png" rel="icon" sizes="48x48" type="image/png"/><link href="/images/favicon-57x57.png" rel="icon" sizes="57x57" type="image/png"/><link href="/images/favicon-64x64.png" rel="icon" sizes="64x64" type="image/png"/><link href="/images/favicon-72x72.png" rel="icon" sizes="72x72" type="image/png"/><link href="/images/favicon-120x120.png" rel="icon" sizes="120x120" type="image/png"/><link href="/images/favicon-152x152.png" rel="icon" sizes="152x152" type="image/png"/><link href="/images/site.webmanifest" rel="manifest"/><meta content="#000000" name="msapplication-TileColor"/><meta content="#000000" name="theme-color"/><style data-styled="" data-styled-version="5.2.1">.eIkvRy{-webkit-flex:none;-ms-flex:none;flex:none;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;font-size:0;width:18px;height:18px;margin-right:4px;}/*!sc*/
# data-styled.g3[id="sc-bdfBwQ"]{content:"eIkvRy,"}/*!sc*/
# .bcaJjD{display:block;}/*!sc*/
# data-styled.g5[id="sc-dlfnbm"]{content:"bcaJjD,"}/*!sc*/
# .eFWsxw{border:0;outline:none;box-sizing:border-box;margin:0;padding:0;-webkit-flex:initial;-ms-flex:initial;flex:initial;box-sizing:border-box;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-flex-direction:row;-ms-flex-direction:row;flex-direction:row;}/*!sc*/
# .eFWsxw:not(:disabled):not(.disabled){cursor:pointer;}/*!sc*/
# .eFWsxw.disabled{cursor:not-allowed;}/*!sc*/
# data-styled.g6[id="sc-hKgILt"]{content:"eFWsxw,"}/*!sc*/
# .hmocIu{-webkit-flex:none;-ms-flex:none;flex:none;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}/*!sc*/
# data-styled.g7[id="sc-eCssSg"]{content:"hmocIu,"}/*!sc*/
# .ckDfJz{margin:0;padding:0;-webkit-flex:initial;-ms-flex:initial;flex:initial;box-sizing:border-box;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}/*!sc*/
# .ckDfJz:not(:disabled):not(.disabled){cursor:pointer;}/*!sc*/
# .ckDfJz.disabled{cursor:not-allowed;}/*!sc*/
# .ckDfJz.disabled{cursor:not-allowed;}/*!sc*/
# data-styled.g8[id="sc-jSgupP"]{content:"ckDfJz,"}/*!sc*/
# .BzhTL{width:100%;height:100%;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-text-decoration:none;text-decoration:none;-webkit-flex-direction:row;-ms-flex-direction:row;flex-direction:row;}/*!sc*/
# .disabled .sc-gKsewC{pointer-events:none;}/*!sc*/
# data-styled.g9[id="sc-gKsewC"]{content:"BzhTL,"}/*!sc*/
# .kiOWAN{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;-webkit-flex:none;-ms-flex:none;flex:none;vertical-align:middle;padding:0;border-radius:3px;color:#1b1c1d;background-color:transparent;width:32px;height:32px;-webkit-transition:background-color 0.1s;transition:background-color 0.1s;}/*!sc*/
# .kiOWAN:hover,.kiOWAN:active{background-color:rgba(248,248,249,0.2);-webkit-text-decoration-line:none;text-decoration-line:none;}/*!sc*/
# .kiOWAN.disabled{color:#dde0e2;background-color:transparent;}/*!sc*/
# .ivGUHd{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;-webkit-flex:none;-ms-flex:none;flex:none;vertical-align:middle;padding:0;border-radius:3px;color:#3e4042;background-color:#FFF;width:32px;height:32px;-webkit-transition:background-color 0.1s;transition:background-color 0.1s;}/*!sc*/
# .ivGUHd:hover,.ivGUHd:active{background-color:#e6e6e6;-webkit-text-decoration-line:none;text-decoration-line:none;}/*!sc*/
# .ivGUHd.disabled{color:#dde0e2;background-color:#FFF;}/*!sc*/
# data-styled.g16[id="sc-crrsfI"]{content:"kiOWAN,ivGUHd,"}/*!sc*/
# .lmqoXt{font-size:11px;font-weight:600;color:#1b1c1d;line-height:16px;-webkit-letter-spacing:normal;-moz-letter-spacing:normal;-ms-letter-spacing:normal;letter-spacing:normal;margin:0;margin:0;}/*!sc*/
# @media (min-width:1024px){.lmqoXt{font-size:11px;font-weight:600;color:#1b1c1d;line-height:16px;-webkit-letter-spacing:normal;-moz-letter-spacing:normal;-ms-letter-spacing:normal;letter-spacing:normal;margin:0;margin:0;}}/*!sc*/
# .jBhEXP{font-size:14px;font-weight:500;color:#1b1c1d;line-height:20px;-webkit-letter-spacing:-0.15px;-moz-letter-spacing:-0.15px;-ms-letter-spacing:-0.15px;letter-spacing:-0.15px;margin:0;margin:0;}/*!sc*/
# .kNZlUM{font-size:20px;font-weight:bold;color:#1b1c1d;line-height:28px;margin:0;margin:0;}/*!sc*/
# .epAcaS{font-size:20px;font-weight:bold;color:#1b1c1d;line-height:28px;margin:0;margin:0;}/*!sc*/
# @media (max-width:1023px){.epAcaS{font-size:18px;font-weight:bold;color:#1b1c1d;line-height:24px;-webkit-letter-spacing:-0.45px;-moz-letter-spacing:-0.45px;-ms-letter-spacing:-0.45px;letter-spacing:-0.45px;margin:0;margin:0;}}/*!sc*/
# @media (min-width:1024px){.epAcaS{font-size:24px;font-weight:bold;color:#1b1c1d;line-height:34px;-webkit-letter-spacing:-0.4px;-moz-letter-spacing:-0.4px;-ms-letter-spacing:-0.4px;letter-spacing:-0.4px;margin:0;margin:0;}}/*!sc*/
# .gpjCoc{font-size:9px;font-weight:600;color:#1b1c1d;line-height:12px;-webkit-letter-spacing:normal;-moz-letter-spacing:normal;-ms-letter-spacing:normal;letter-spacing:normal;margin:0;margin:0;}/*!sc*/
# @media (min-width:1024px){.gpjCoc{font-size:11px;font-weight:600;color:#1b1c1d;line-height:16px;-webkit-letter-spacing:normal;-moz-letter-spacing:normal;-ms-letter-spacing:normal;letter-spacing:normal;margin:0;margin:0;}}/*!sc*/
# .ijMXBg{font-size:9px;font-weight:normal;color:#a8aeb3;line-height:12px;-webkit-letter-spacing:normal;-moz-letter-spacing:normal;-ms-letter-spacing:normal;letter-spacing:normal;margin:0;margin:0;}/*!sc*/
# .kgbqfx{font-size:14px;font-weight:normal;color:#1b1c1d;line-height:20px;-webkit-letter-spacing:-0.15px;-moz-letter-spacing:-0.15px;-ms-letter-spacing:-0.15px;letter-spacing:-0.15px;margin:0;margin:0;}/*!sc*/
# .kaYBCB{font-size:24px;font-weight:bold;color:#1b1c1d;line-height:34px;-webkit-letter-spacing:-0.4px;-moz-letter-spacing:-0.4px;-ms-letter-spacing:-0.4px;letter-spacing:-0.4px;margin:0;margin:0;}/*!sc*/
# .euEhID{font-size:16px;font-weight:bold;color:#1b1c1d;line-height:24px;-webkit-letter-spacing:-0.3px;-moz-letter-spacing:-0.3px;-ms-letter-spacing:-0.3px;letter-spacing:-0.3px;margin:0;margin:0;}/*!sc*/
# @media (min-width:1024px){.euEhID{font-size:20px;font-weight:bold;color:#1b1c1d;line-height:28px;margin:0;margin:0;}}/*!sc*/
# .kXqfXN{font-size:11px;font-weight:normal;color:#1b1c1d;line-height:16px;-webkit-letter-spacing:normal;-moz-letter-spacing:normal;-ms-letter-spacing:normal;letter-spacing:normal;margin:0;margin:0;}/*!sc*/
# @media (min-width:1024px){.kXqfXN{font-size:14px;font-weight:normal;color:#1b1c1d;line-height:20px;-webkit-letter-spacing:-0.15px;-moz-letter-spacing:-0.15px;-ms-letter-spacing:-0.15px;letter-spacing:-0.15px;margin:0;margin:0;}}/*!sc*/
# .hZJNKT{font-size:14px;font-weight:bold;color:#1b1c1d;line-height:20px;-webkit-letter-spacing:-0.15px;-moz-letter-spacing:-0.15px;-ms-letter-spacing:-0.15px;letter-spacing:-0.15px;margin:0;margin:0;}/*!sc*/
# .dZAmQV{font-size:11px;font-weight:normal;color:#1b1c1d;line-height:16px;-webkit-letter-spacing:normal;-moz-letter-spacing:normal;-ms-letter-spacing:normal;letter-spacing:normal;margin:0;margin:0;}/*!sc*/
# data-styled.g17[id="sc-dQppl"]{content:"lmqoXt,jBhEXP,kNZlUM,epAcaS,gpjCoc,ijMXBg,kgbqfx,kaYBCB,euEhID,kXqfXN,hZJNKT,dZAmQV,"}/*!sc*/
# .bcnlOH{width:auto;display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;vertical-align:middle;border-radius:3px;color:#1b1c1d;background-color:#f8f8f9;font-weight:500;font-size:14px;-webkit-letter-spacing:-0.2px;-moz-letter-spacing:-0.2px;-ms-letter-spacing:-0.2px;letter-spacing:-0.2px;padding:0 16px;height:40px;-webkit-transition:background-color 0.1s;transition:background-color 0.1s;-webkit-text-decoration-line:none;text-decoration-line:none;}/*!sc*/
# .bcnlOH > a{color:#1b1c1d;}/*!sc*/
# .bcnlOH:hover,.bcnlOH:active{background-color:#dddde1;}/*!sc*/
# .bcnlOH.disabled{color:#dde0e2;background-color:#f8f8f9;}/*!sc*/
# .eFOcUb{width:auto;display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;vertical-align:middle;border-radius:3px;color:#FFF;background-color:#ff922b;font-weight:500;font-size:14px;-webkit-letter-spacing:-0.2px;-moz-letter-spacing:-0.2px;-ms-letter-spacing:-0.2px;letter-spacing:-0.2px;padding:0 16px;height:40px;-webkit-transition:background-color 0.1s;transition:background-color 0.1s;-webkit-text-decoration-line:none;text-decoration-line:none;}/*!sc*/
# .eFOcUb > a{color:#FFF;}/*!sc*/
# .eFOcUb:hover,.eFOcUb:active{background-color:#f77800;}/*!sc*/
# .eFOcUb.disabled{color:#FFF;background-color:#ffe8cc;}/*!sc*/
# .qilEJ{width:100%;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;vertical-align:middle;border-radius:3px;color:#FFF;background-color:#ff922b;font-weight:700;font-size:16px;-webkit-letter-spacing:-0.2px;-moz-letter-spacing:-0.2px;-ms-letter-spacing:-0.2px;letter-spacing:-0.2px;padding:0 20px;height:48px;-webkit-transition:background-color 0.1s;transition:background-color 0.1s;-webkit-text-decoration-line:none;text-decoration-line:none;}/*!sc*/
# .qilEJ > a{color:#FFF;}/*!sc*/
# .qilEJ:hover,.qilEJ:active{background-color:#f77800;}/*!sc*/
# .qilEJ.disabled{color:#FFF;background-color:#ffe8cc;}/*!sc*/
# .cBeoZY{width:100%;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;vertical-align:middle;border-radius:3px;color:#1b1c1d;background-color:#f8f8f9;font-weight:500;font-size:14px;-webkit-letter-spacing:-0.2px;-moz-letter-spacing:-0.2px;-ms-letter-spacing:-0.2px;letter-spacing:-0.2px;padding:0 16px;height:40px;-webkit-transition:background-color 0.1s;transition:background-color 0.1s;-webkit-text-decoration-line:none;text-decoration-line:none;}/*!sc*/
# .cBeoZY > a{color:#1b1c1d;}/*!sc*/
# .cBeoZY:hover,.cBeoZY:active{background-color:#dddde1;}/*!sc*/
# .cBeoZY.disabled{color:#dde0e2;background-color:#f8f8f9;}/*!sc*/
# data-styled.g18[id="sc-bqyKva"]{content:"bcnlOH,eFOcUb,qilEJ,cBeoZY,"}/*!sc*/
# .ffCxYv{margin-bottom:2px;}/*!sc*/
# .iPVNkj{margin-top:4px;margin-right:4px;}/*!sc*/
# .keNqyV{margin-top:4px;}/*!sc*/
# .eujIhT{margin-bottom:24px;}/*!sc*/
# .cwFQdY{margin-top:24px;margin-bottom:24px;}/*!sc*/
# .jTmoQW{margin-bottom:16px;}/*!sc*/
# .iLaWJb{margin-top:24px;}/*!sc*/
# .djUmEc{margin-bottom:72px;}/*!sc*/
# data-styled.g20[id="Spacing__Box-sc-47wgmh-0"]{content:"ffCxYv,iLryzw,iPVNkj,keNqyV,eujIhT,cwFQdY,jTmoQW,iLaWJb,djUmEc,"}/*!sc*/
# .johiBf:hover{color:inherit;}/*!sc*/
# data-styled.g22[id="LinkComponent__Anchor-gmbdn6-0"]{content:"johiBf,"}/*!sc*/
# .hYxdXM:hover{color:inherit;}/*!sc*/
# data-styled.g23[id="LinkComponent__StyledLink-gmbdn6-1"]{content:"hYxdXM,"}/*!sc*/
# .cHyuRA{background-color:#edeff0;border-radius:3px;border-radius:50%;-webkit-animation:hllEEO 1s infinite linear alternate;animation:hllEEO 1s infinite linear alternate;}/*!sc*/
# .VhKAT{background-color:#edeff0;border-radius:3px;-webkit-animation:hllEEO 1s infinite linear alternate;animation:hllEEO 1s infinite linear alternate;}/*!sc*/
# data-styled.g26[id="sc-hBEYos"]{content:"cHyuRA,VhKAT,"}/*!sc*/
# .cYLuAZ{opacity:0;}/*!sc*/
# data-styled.g27[id="sc-fodVxV"]{content:"cYLuAZ,"}/*!sc*/
# .blDEng img{width:100%;height:100%;object-fit:cover;}/*!sc*/
# data-styled.g28[id="ResponsiveImage__Picture-sc-18ezuwf-0"]{content:"blDEng,"}/*!sc*/
# .kDHWPV{display:block;position:relative;overflow:hidden;font-size:0;padding-top:75%;background:#eee;}/*!sc*/
# .hjzEDS{display:block;position:relative;overflow:hidden;font-size:0;padding-top:100%;background:#eee;}/*!sc*/
# .bHVtPL{display:block;position:relative;overflow:hidden;font-size:0;background:#eee;}/*!sc*/
# data-styled.g31[id="RatioImage__Container-sc-1riu4nv-0"]{content:"kDHWPV,hjzEDS,bHVtPL,"}/*!sc*/
# .jXjBqF{opacity:0.1;-webkit-transition:opacity 150ms linear;transition:opacity 150ms linear;}/*!sc*/
# data-styled.g33[id="ContentImage__Img-tg6jfv-0"]{content:"jXjBqF,"}/*!sc*/
# .emTpmL{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;width:100%;}/*!sc*/
# @media (max-width:1023px){.emTpmL{height:80px;}}/*!sc*/
# @media (min-width:1024px){.emTpmL{height:80px;}}/*!sc*/
# data-styled.g36[id="BeltBanner__BeltBannerSkeleton-g5trh3-0"]{content:"emTpmL,"}/*!sc*/
# .swiper-container{margin:0 auto;position:relative;overflow:hidden;list-style:none;padding:0;z-index:1;}/*!sc*/
# .swiper-container-no-flexbox .swiper-slide{float:left;}/*!sc*/
# .swiper-container-vertical > .swiper-wrapper{-webkit-box-orient:vertical;-webkit-box-direction:normal;-webkit-flex-direction:column;-ms-flex-direction:column;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;}/*!sc*/
# .swiper-wrapper{position:relative;width:100%;height:100%;z-index:1;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-transition-property:-webkit-transform;-webkit-transition-property:-webkit-transform;-webkit-transition-property:-webkit-transform;transition-property:-webkit-transform;-o-transition-property:transform;-webkit-transition-property:-webkit-transform;-webkit-transition-property:transform;transition-property:transform;-webkit-transition-property:-webkit-transform,-webkit-transform;-webkit-transition-property:transform,-webkit-transform;transition-property:transform,-webkit-transform;-webkit-box-sizing:content-box;box-sizing:content-box;}/*!sc*/
# .swiper-container-android .swiper-slide,.swiper-wrapper{-webkit-transform:translate3d(0px,0,0);-webkit-transform:translate3d(0px,0,0);-ms-transform:translate3d(0px,0,0);transform:translate3d(0px,0,0);}/*!sc*/
# .swiper-container-multirow > .swiper-wrapper{-webkit-flex-wrap:wrap;-ms-flex-wrap:wrap;-webkit-flex-wrap:wrap;-ms-flex-wrap:wrap;flex-wrap:wrap;}/*!sc*/
# .swiper-container-free-mode > .swiper-wrapper{-webkit-transition-timing-function:ease-out;-o-transition-timing-function:ease-out;-webkit-transition-timing-function:ease-out;transition-timing-function:ease-out;margin:0 auto;}/*!sc*/
# .swiper-slide{-webkit-flex-shrink:0;-ms-flex-negative:0;-webkit-flex-shrink:0;-ms-flex-negative:0;flex-shrink:0;width:100%;height:100%;position:relative;-webkit-transition-property:-webkit-transform;-webkit-transition-property:-webkit-transform;-webkit-transition-property:-webkit-transform;transition-property:-webkit-transform;-o-transition-property:transform;-webkit-transition-property:-webkit-transform;-webkit-transition-property:transform;transition-property:transform;-webkit-transition-property:-webkit-transform,-webkit-transform;-webkit-transition-property:transform,-webkit-transform;transition-property:transform,-webkit-transform;}/*!sc*/
# .swiper-slide-invisible-blank{visibility:hidden;}/*!sc*/
# .swiper-container-autoheight,.swiper-container-autoheight .swiper-slide{height:auto;}/*!sc*/
# .swiper-container-autoheight .swiper-wrapper{-webkit-box-align:start;-webkit-align-items:flex-start;-ms-flex-align:start;-webkit-align-items:flex-start;-webkit-box-align:flex-start;-ms-flex-align:flex-start;align-items:flex-start;-webkit-transition-property:height,-webkit-transform;-webkit-transition-property:height,-webkit-transform;-webkit-transition-property:height,-webkit-transform;transition-property:height,-webkit-transform;-o-transition-property:transform,height;-webkit-transition-property:-webkit-transform,height;-webkit-transition-property:transform,height;transition-property:transform,height;-webkit-transition-property:-webkit-transform,height,-webkit-transform;-webkit-transition-property:transform,height,-webkit-transform;transition-property:transform,height,-webkit-transform;}/*!sc*/
# .swiper-container-wp8-horizontal,.swiper-container-wp8-horizontal > .swiper-wrapper{-ms-touch-action:pan-y;touch-action:pan-y;}/*!sc*/
# .swiper-container-wp8-vertical,.swiper-container-wp8-vertical > .swiper-wrapper{-ms-touch-action:pan-x;touch-action:pan-x;}/*!sc*/
# .swiper-button-prev,.swiper-button-next{position:absolute;top:50%;width:27px;height:44px;margin-top:-22px;z-index:10;cursor:pointer;background-size:27px 44px;background-position:center;background-repeat:no-repeat;}/*!sc*/
# .swiper-button-prev.swiper-button-disabled,.swiper-button-next.swiper-button-disabled{opacity:0.35;cursor:auto;pointer-events:none;}/*!sc*/
# .swiper-button-lock{display:none;}/*!sc*/
# .swiper-pagination{position:absolute;text-align:center;-webkit-transition:300ms opacity;-o-transition:300ms opacity;-webkit-transition:300ms opacity;transition:300ms opacity;-webkit-transform:translate3d(0,0,0);-webkit-transform:translate3d(0,0,0);-ms-transform:translate3d(0,0,0);transform:translate3d(0,0,0);z-index:10;pointer-events:none;}/*!sc*/
# .swiper-pagination.swiper-pagination-hidden{opacity:0;}/*!sc*/
# .swiper-pagination-fraction,.swiper-pagination-custom,.swiper-container-horizontal > .swiper-pagination-bullets{bottom:10px;left:0;width:100%;}/*!sc*/
# .swiper-pagination-bullets-dynamic{overflow:hidden;font-size:0;}/*!sc*/
# .swiper-pagination-bullets-dynamic .swiper-pagination-bullet{-webkit-transform:scale(0.33);-ms-transform:scale(0.33);-webkit-transform:scale(0.33);-ms-transform:scale(0.33);transform:scale(0.33);position:relative;}/*!sc*/
# .swiper-pagination-bullets-dynamic .swiper-pagination-bullet-active{-webkit-transform:scale(1);-ms-transform:scale(1);-webkit-transform:scale(1);-ms-transform:scale(1);transform:scale(1);}/*!sc*/
# .swiper-pagination-bullets-dynamic .swiper-pagination-bullet-active-main{-webkit-transform:scale(1);-ms-transform:scale(1);-webkit-transform:scale(1);-ms-transform:scale(1);transform:scale(1);}/*!sc*/
# .swiper-pagination-bullets-dynamic .swiper-pagination-bullet-active-prev{-webkit-transform:scale(0.66);-ms-transform:scale(0.66);-webkit-transform:scale(0.66);-ms-transform:scale(0.66);transform:scale(0.66);}/*!sc*/
# .swiper-pagination-bullets-dynamic .swiper-pagination-bullet-active-prev-prev{-webkit-transform:scale(0.33);-ms-transform:scale(0.33);-webkit-transform:scale(0.33);-ms-transform:scale(0.33);transform:scale(0.33);}/*!sc*/
# .swiper-pagination-bullets-dynamic .swiper-pagination-bullet-active-next{-webkit-transform:scale(0.66);-ms-transform:scale(0.66);-webkit-transform:scale(0.66);-ms-transform:scale(0.66);transform:scale(0.66);}/*!sc*/
# .swiper-pagination-bullets-dynamic .swiper-pagination-bullet-active-next-next{-webkit-transform:scale(0.33);-ms-transform:scale(0.33);-webkit-transform:scale(0.33);-ms-transform:scale(0.33);transform:scale(0.33);}/*!sc*/
# .swiper-pagination-bullet{width:8px;height:8px;display:inline-block;border-radius:100%;background:#000;opacity:0.2;pointer-events:auto;}/*!sc*/
# button.swiper-pagination-bullet{border:none;margin:0;padding:0;-webkit-box-shadow:none;box-shadow:none;-webkit-appearance:none;-moz-appearance:none;-webkit-appearance:none;-moz-appearance:none;appearance:none;}/*!sc*/
# .swiper-pagination-clickable .swiper-pagination-bullet{cursor:pointer;}/*!sc*/
# .swiper-pagination-bullet-active{opacity:1;background:#007aff;}/*!sc*/
# .swiper-container-vertical > .swiper-pagination-bullets{right:10px;top:50%;-webkit-transform:translate3d(0px,-50%,0);-webkit-transform:translate3d(0px,-50%,0);-ms-transform:translate3d(0px,-50%,0);transform:translate3d(0px,-50%,0);}/*!sc*/
# .swiper-container-vertical > .swiper-pagination-bullets .swiper-pagination-bullet{margin:6px 0;display:block;}/*!sc*/
# .swiper-container-vertical > .swiper-pagination-bullets.swiper-pagination-bullets-dynamic{top:50%;-webkit-transform:translateY(-50%);-ms-transform:translateY(-50%);-webkit-transform:translateY(-50%);-ms-transform:translateY(-50%);transform:translateY(-50%);width:8px;}/*!sc*/
# .swiper-container-vertical > .swiper-pagination-bullets.swiper-pagination-bullets-dynamic .swiper-pagination-bullet{display:inline-block;-webkit-transition:200ms top,200ms -webkit-transform;-webkit-transition:200ms top,200ms -webkit-transform;-webkit-transition:200ms top,200ms -webkit-transform;transition:200ms top,200ms -webkit-transform;-o-transition:200ms transform,200ms top;-webkit-transition:200ms -webkit-transform,200ms top;-webkit-transition:200ms transform,200ms top;transition:200ms transform,200ms top;-webkit-transition:200ms -webkit-transform,200ms top,200ms -webkit-transform;-webkit-transition:200ms transform,200ms top,200ms -webkit-transform;transition:200ms transform,200ms top,200ms -webkit-transform;}/*!sc*/
# .swiper-container-horizontal > .swiper-pagination-bullets .swiper-pagination-bullet{margin:0 4px;}/*!sc*/
# .swiper-container-horizontal > .swiper-pagination-bullets.swiper-pagination-bullets-dynamic{left:50%;-webkit-transform:translateX(-50%);-ms-transform:translateX(-50%);-webkit-transform:translateX(-50%);-ms-transform:translateX(-50%);transform:translateX(-50%);white-space:nowrap;}/*!sc*/
# .swiper-container-horizontal > .swiper-pagination-bullets.swiper-pagination-bullets-dynamic .swiper-pagination-bullet{-webkit-transition:200ms left,200ms -webkit-transform;-webkit-transition:200ms left,200ms -webkit-transform;-webkit-transition:200ms left,200ms -webkit-transform;transition:200ms left,200ms -webkit-transform;-o-transition:200ms transform,200ms left;-webkit-transition:200ms -webkit-transform,200ms left;-webkit-transition:200ms transform,200ms left;transition:200ms transform,200ms left;-webkit-transition:200ms -webkit-transform,200ms left,200ms -webkit-transform;-webkit-transition:200ms transform,200ms left,200ms -webkit-transform;transition:200ms transform,200ms left,200ms -webkit-transform;}/*!sc*/
# .swiper-container-horizontal.swiper-container-rtl > .swiper-pagination-bullets-dynamic .swiper-pagination-bullet{-webkit-transition:200ms right,200ms -webkit-transform;-webkit-transition:200ms right,200ms -webkit-transform;-webkit-transition:200ms right,200ms -webkit-transform;transition:200ms right,200ms -webkit-transform;-o-transition:200ms transform,200ms right;-webkit-transition:200ms -webkit-transform,200ms right;-webkit-transition:200ms transform,200ms right;transition:200ms transform,200ms right;-webkit-transition:200ms -webkit-transform,200ms right,200ms -webkit-transform;-webkit-transition:200ms transform,200ms right,200ms -webkit-transform;transition:200ms transform,200ms right,200ms -webkit-transform;}/*!sc*/
# .swiper-pagination-white .swiper-pagination-bullet-active{background:#ffffff;}/*!sc*/
# .swiper-pagination-black .swiper-pagination-bullet-active{background:#000000;}/*!sc*/
# .swiper-pagination-lock{display:none;}/*!sc*/
# .swiper-container .swiper-notification{position:absolute;left:0;top:0;pointer-events:none;opacity:0;z-index:-1000;}/*!sc*/
# .swiper-container-fade.swiper-container-free-mode .swiper-slide{-webkit-transition-timing-function:ease-out;-o-transition-timing-function:ease-out;-webkit-transition-timing-function:ease-out;transition-timing-function:ease-out;}/*!sc*/
# .swiper-container-fade .swiper-slide{pointer-events:none;-webkit-transition-property:opacity;-o-transition-property:opacity;-webkit-transition-property:opacity;transition-property:opacity;}/*!sc*/
# .swiper-container-fade .swiper-slide .swiper-slide{pointer-events:none;}/*!sc*/
# .swiper-container-fade .swiper-slide-active,.swiper-container-fade .swiper-slide-active .swiper-slide-active{pointer-events:auto;}/*!sc*/
# .swiper-container-coverflow .swiper-wrapper{-ms-perspective:1200px;}/*!sc*/
# a{-webkit-text-decoration:none;text-decoration:none;color:inherit;}/*!sc*/
# p,ul{padding:0;margin:0;}/*!sc*/
# data-styled.g140[id="sc-global-kTfdpC1"]{content:"sc-global-kTfdpC1,"}/*!sc*/
# .gIiA-dl{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;margin-right:32px;}/*!sc*/
# @media (max-width:1023px){.gIiA-dl{margin-right:8px;}}/*!sc*/
# data-styled.g149[id="Logo__Container-juoklg-0"]{content:"gIiA-dl,"}/*!sc*/
# .bWYGiY{width:110px;height:auto;}/*!sc*/
# @media (max-width:1023px){.bWYGiY{width:80px;height:auto;}}/*!sc*/
# .kjEHil{width:110px;height:auto;}/*!sc*/
# data-styled.g150[id="Logo__MainLogoSvg-juoklg-1"]{content:"bWYGiY,kjEHil,"}/*!sc*/
# .kajamm{position:relative;width:100%;}/*!sc*/
# data-styled.g187[id="sc-citwmv"]{content:"kajamm,"}/*!sc*/
# .hrCIoP{overflow:hidden;border-radius:3px;margin-bottom:8px;}/*!sc*/
# data-styled.g188[id="sc-jcVebW"]{content:"hrCIoP,"}/*!sc*/
# .iioCdK{font-size:14px;font-weight:normal;color:#1b1c1d;line-height:20px;-webkit-letter-spacing:-0.15px;-moz-letter-spacing:-0.15px;-ms-letter-spacing:-0.15px;letter-spacing:-0.15px;margin:0;color:#1b1c1d;height:40px;overflow:hidden;margin-bottom:6px;display:-webkit-box;-webkit-line-clamp:2;-webkit-box-orient:vertical;}/*!sc*/
# data-styled.g191[id="sc-iBaPrD"]{content:"iioCdK,"}/*!sc*/
# .JiLrb{margin-bottom:4px;margin-top:4px;}/*!sc*/
# data-styled.g192[id="sc-eggNIi"]{content:"JiLrb,"}/*!sc*/
# .lhXIuw.swiper-button-prev,.lhXIuw.swiper-button-next{box-shadow:0px 1px 3px rgba(41,42,43,0.1),0px 0px 0.5px rgba(0,0,0,0.04);width:32px;height:32px;background-image:none;margin:0;position:absolute;top:0;left:auto;}/*!sc*/
# .lhXIuw.swiper-button-prev:focus,.lhXIuw.swiper-button-next:focus{outline:none;}/*!sc*/
# .lhXIuw.swiper-button-prev:not(.swiper-button-disabled):active,.lhXIuw.swiper-button-next:not(.swiper-button-disabled):active{opacity:1;pointer-events:auto;}/*!sc*/
# .lhXIuw.swiper-button-prev.swiper-button-disabled,.lhXIuw.swiper-button-next.swiper-button-disabled{pointer-events:auto;cursor:not-allowed;}/*!sc*/
# .lhXIuw.swiper-button-prev{right:32px;border-top-right-radius:0;border-bottom-right-radius:0;}/*!sc*/
# .lhXIuw.swiper-button-next{right:0;border-top-left-radius:0;border-bottom-left-radius:0;}/*!sc*/
# data-styled.g195[id="sc-dOSReg"]{content:"lhXIuw,"}/*!sc*/
# .bjaYAZ{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:end;-webkit-justify-content:flex-end;-ms-flex-pack:end;justify-content:flex-end;-webkit-box-flex:1;-webkit-flex-grow:1;-ms-flex-positive:1;flex-grow:1;}/*!sc*/
# @media (max-width:1023px){.bjaYAZ{-webkit-box-flex:0;-webkit-flex-grow:0;-ms-flex-positive:0;flex-grow:0;}}/*!sc*/
# data-styled.g207[id="AuthSkeleton__Container-sc-1pzx34o-0"]{content:"bjaYAZ,"}/*!sc*/
# .gIAZrv{min-width:24px;height:24px;border-radius:3px;padding-left:6px;padding-right:6px;background-color:#f8f8f9;-webkit-flex:none;-ms-flex:none;flex:none;display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;box-sizing:border-box;}/*!sc*/
# .gIAZrv svg{width:12px;height:12px;}/*!sc*/
# .dguoob{min-width:20px;height:20px;border-radius:3px;padding-left:6px;padding-right:6px;background-color:#f8f8f9;-webkit-flex:none;-ms-flex:none;flex:none;display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;box-sizing:border-box;}/*!sc*/
# .dguoob svg{width:12px;height:12px;}/*!sc*/
# data-styled.g223[id="sc-hTZhsR"]{content:"gIAZrv,dguoob,"}/*!sc*/
# .OkKCO{font-size:11px;font-weight:normal;color:#f33340;line-height:16px;-webkit-letter-spacing:normal;-moz-letter-spacing:normal;-ms-letter-spacing:normal;letter-spacing:normal;margin:0;font-weight:600;display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}/*!sc*/
# .OkKCO color:function(n){return"DARK"===n.theme.mode?e:t;}/*!sc*/
# .ibwvyr{font-size:11px;font-weight:normal;color:#858a8d;line-height:16px;-webkit-letter-spacing:normal;-moz-letter-spacing:normal;-ms-letter-spacing:normal;letter-spacing:normal;margin:0;font-weight:600;display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}/*!sc*/
# .ibwvyr color:function(n){return"DARK"===n.theme.mode?e:t;}/*!sc*/
# .hVtEoh{font-size:9px;font-weight:normal;color:#f33340;line-height:12px;-webkit-letter-spacing:normal;-moz-letter-spacing:normal;-ms-letter-spacing:normal;letter-spacing:normal;margin:0;color:#f33340;font-weight:600;display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}/*!sc*/
# .dbSViV{font-size:9px;font-weight:normal;color:#858a8d;line-height:12px;-webkit-letter-spacing:normal;-moz-letter-spacing:normal;-ms-letter-spacing:normal;letter-spacing:normal;margin:0;color:#858a8d;font-weight:600;display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}/*!sc*/
# data-styled.g225[id="sc-gTgzIj"]{content:"OkKCO,ibwvyr,hVtEoh,dbSViV,"}/*!sc*/
# .hfPqWT{margin:0 !important;box-shadow:inset 0px -1px 0px #f8f8f9;border:none;height:1px;}/*!sc*/
# .kQhlQU{margin:0 !important;box-shadow:inset 0px -1px 0px #edeff0;border:none;height:1px;}/*!sc*/
# data-styled.g275[id="sc-nFpLZ"]{content:"hfPqWT,kQhlQU,"}/*!sc*/
# .dxYbvt img{border-radius:3px;}/*!sc*/
# data-styled.g276[id="Thumbnail-sc-1sevrw-0"]{content:"dxYbvt,"}/*!sc*/
# .dVlREr{position:relative;}/*!sc*/
# .dVlREr:before,.dVlREr:after{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;white-space:pre;position:absolute;z-index:1;}/*!sc*/
# .dVlREr:before{content:'';top:0;left:0;width:100%;height:100%;background-color:rgba(27,28,29,0.8);border-radius:3px;}/*!sc*/
# .dVlREr:after{font-size:14px;font-weight:normal;color:#1b1c1d;line-height:20px;-webkit-letter-spacing:-0.15px;-moz-letter-spacing:-0.15px;-ms-letter-spacing:-0.15px;letter-spacing:-0.15px;margin:0;top:50%;left:50%;width:25px;-webkit-transform:translate(-50%,-50%);-ms-transform:translate(-50%,-50%);transform:translate(-50%,-50%);content:'더보기';font-weight:bold;color:white;text-align:center;}/*!sc*/
# data-styled.g277[id="ThumbnailOverlay-sc-77phk-0"]{content:"dVlREr,"}/*!sc*/
# .iGIdiM{position:relative;width:100%;padding-top:100%;border-radius:3px;overflow:hidden;}/*!sc*/
# data-styled.g278[id="RatioContainer__Container-sc-1v4i457-0"]{content:"iGIdiM,"}/*!sc*/
# .ejYLNp{position:absolute;top:0;left:0;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;width:100%;height:100%;}/*!sc*/
# data-styled.g279[id="RatioContainer__Inner-sc-1v4i457-1"]{content:"ejYLNp,"}/*!sc*/
# .OTOBb{position:relative;min-height:1px;padding-right:12px;padding-left:12px;box-sizing:border-box;}/*!sc*/
# @media (max-width:1023px){.OTOBb{width:100%;padding-right:4px;padding-left:4px;}}/*!sc*/
# @media{.OTOBb{width:100%;}}/*!sc*/
# @media (min-width:1024px){.OTOBb{width:66.66666666666666%;}}/*!sc*/
# .jQvOTz{position:relative;min-height:1px;padding-right:12px;padding-left:12px;box-sizing:border-box;}/*!sc*/
# @media (max-width:1023px){.jQvOTz{width:100%;padding-right:4px;padding-left:4px;}}/*!sc*/
# @media{.jQvOTz{width:100%;}}/*!sc*/
# @media (min-width:1024px){.jQvOTz{width:33.33333333333333%;}}/*!sc*/
# .dCVMUQ{position:relative;min-height:1px;padding-right:12px;padding-left:12px;box-sizing:border-box;}/*!sc*/
# @media (max-width:1023px){.dCVMUQ{width:100%;padding-right:4px;padding-left:4px;}}/*!sc*/
# @media{.dCVMUQ{width:100%;}}/*!sc*/
# @media (min-width:1024px){.dCVMUQ{width:100%;}}/*!sc*/
# data-styled.g314[id="sc-jONnTn"]{content:"OTOBb,jQvOTz,dCVMUQ,"}/*!sc*/
# .bkPOGA{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-wrap:wrap;-ms-flex-wrap:wrap;flex-wrap:wrap;-webkit-box-pack:start;-webkit-justify-content:flex-start;-ms-flex-pack:start;justify-content:flex-start;-webkit-align-content:stretch;-ms-flex-line-pack:stretch;align-content:stretch;margin-right:-12px;margin-left:-12px;}/*!sc*/
# @media (max-width:1023px){.bkPOGA{margin-right:-4px;margin-left:-4px;}}/*!sc*/
# data-styled.g315[id="sc-hlTvYk"]{content:"bkPOGA,"}/*!sc*/
# .gfBdMF{display:block;-webkit-flex:none;-ms-flex:none;flex:none;pointer-events:auto;touch-action:auto;width:179px;padding-left:16px;}/*!sc*/
# @media (min-width:1024px){.gfBdMF{width:25%;margin-left:0;padding:8px 8px;}}/*!sc*/
# @media (max-width:1023px){.gfBdMF:first-child{width:187px;padding-left:24px;}.gfBdMF:last-child{width:195px;padding-right:24px;}}/*!sc*/
# @media (max-width:767px){.gfBdMF{width:calc((100vw - 32px) / 2);}.gfBdMF:first-child{width:calc(((100vw - 32px) / 2) + 8px);padding-left:24px;}.gfBdMF:last-child{width:calc(((100vw - 32px) / 2) + 24px);padding-right:24px;}}/*!sc*/
# .eGsmXW{display:block;-webkit-flex:none;-ms-flex:none;flex:none;pointer-events:auto;touch-action:auto;width:359px;padding-left:16px;}/*!sc*/
# @media (min-width:1024px){.eGsmXW{width:25%;margin-left:0;padding:8px 8px;}}/*!sc*/
# @media (max-width:1023px){.eGsmXW:first-child{width:367px;padding-left:24px;}.eGsmXW:last-child{width:375px;padding-right:24px;}}/*!sc*/
# @media (max-width:767px){.eGsmXW{width:calc((100vw - 32px) / 1);}.eGsmXW:first-child{width:calc(((100vw - 32px) / 1) + 8px);padding-left:24px;}.eGsmXW:last-child{width:calc(((100vw - 32px) / 1) + 24px);padding-right:24px;}}/*!sc*/
# data-styled.g327[id="PostMediaItem-a2b40z-0"]{content:"gfBdMF,eGsmXW,"}/*!sc*/
# .cKZthU{height:40px;width:100%;border:0;-webkit-flex:1;-ms-flex:1;flex:1;padding-left:16px;padding-right:44px;font-size:14px;color:#1b1c1d;border-radius:3px;background-color:#FFF;box-shadow:0 0 1px 0 rgba(0,0,0,0.04),0 1px 3px 0 rgba(41,42,43,0.16);}/*!sc*/
# .cKZthU > svg path{fill:#dde0e2;}/*!sc*/
# .cKZthU::-webkit-input-placeholder{color:#3e4042;}/*!sc*/
# .cKZthU::-moz-placeholder{color:#3e4042;}/*!sc*/
# .cKZthU:-ms-input-placeholder{color:#3e4042;}/*!sc*/
# .cKZthU::placeholder{color:#3e4042;}/*!sc*/
# .cKZthU:hover{border:none;}/*!sc*/
# .cKZthU:focus{background-color:#f8f8f9;border-radius:0 3px 0 0;box-shadow:0 0 1px 0 rgba(0,0,0,0.06),-0.5px 0 0 0 rgba(0,0,0,0.03);}/*!sc*/
# data-styled.g447[id="SearchInputBox__SearchBox-vnhzzn-0"]{content:"cKZthU,"}/*!sc*/
# .iZRCEX{position:absolute;top:0;right:0;width:44px;height:40px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;cursor:pointer;}/*!sc*/
# data-styled.g448[id="SearchInputBox__IconWrapper-vnhzzn-1"]{content:"iZRCEX,"}/*!sc*/
# .gECeAV{width:20px;height:20px;}/*!sc*/
# @media (max-width:1023px){.gECeAV{width:14px;height:14px;}}/*!sc*/
# data-styled.g449[id="SearchInputBox__SearchIcon-vnhzzn-2"]{content:"gECeAV,"}/*!sc*/
# .dRVcQy{position:relative;z-index:1901;width:100%;height:40px;background-color:#FFF;}/*!sc*/
# data-styled.g450[id="SearchInputBox__Container-vnhzzn-3"]{content:"dRVcQy,"}/*!sc*/
# .fRVALD{position:fixed;top:0px;bottom:0px;left:0px;right:0px;opacity:0;z-index:1900;display:none;}/*!sc*/
# data-styled.g451[id="SearchInputBox__Background-vnhzzn-4"]{content:"fRVALD,"}/*!sc*/
# .llWyCx{position:relative;}/*!sc*/
# @media (min-width:1116px){.llWyCx{width:100%;-webkit-transition:0.6s cubic-bezier(0.42,0,0.2,1);transition:0.6s cubic-bezier(0.42,0,0.2,1);}.llWyCx:focus-within{width:420px;-webkit-transition:0.4s cubic-bezier(0.42,0,0.2,1);transition:0.4s cubic-bezier(0.42,0,0.2,1);}}/*!sc*/
# @media (max-width:1023px){.llWyCx{position:static;}}/*!sc*/
# data-styled.g452[id="ProductKeywordListViewController__Container-sc-1ijv81c-0"]{content:"llWyCx,"}/*!sc*/
# .jgTrAr{position:relative;background-color:white;box-shadow:inset 0px -1px 0px #f8f8f9;}/*!sc*/
# data-styled.g472[id="MainHeader__HeaderWrapper-sc-5di1wa-0"]{content:"jgTrAr,"}/*!sc*/
# .golaN{margin-left:24px;margin-right:24px;padding:14px 0;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;position:relative;}/*!sc*/
# @media (min-width:1024px) and (max-width:1239px){.golaN{margin-left:32px;margin-right:32px;}}/*!sc*/
# @media (min-width:1240px){.golaN{max-width:1176px;width:100%;margin-left:auto;margin-right:auto;}}/*!sc*/
# @media (max-width:1023px){.golaN{padding:8px 0px 8px 16px;margin-left:0px;margin-right:16px;}}/*!sc*/
# data-styled.g473[id="MainHeader__UtilContainer-sc-5di1wa-1"]{content:"golaN,"}/*!sc*/
# .jRosOF{width:100%;max-width:380px;}/*!sc*/
# @media (max-width:1023px){.jRosOF{max-width:100%;margin:0 12px 0 8px;}}/*!sc*/
# data-styled.g474[id="MainHeader__SearchBoxWrapper-sc-5di1wa-2"]{content:"jRosOF,"}/*!sc*/
# .ezcFZc{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;}/*!sc*/
# data-styled.g475[id="MainHeader__LogoWrapper-sc-5di1wa-3"]{content:"ezcFZc,"}/*!sc*/
# .enlxrs{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;}/*!sc*/
# data-styled.g530[id="style__Row-sc-1jp0bkg-0"]{content:"enlxrs,"}/*!sc*/
# .jbSeHF{margin-top:24px;}/*!sc*/
# @media (max-width:1023px){.jbSeHF{margin-top:56px;padding:0 12px;}}/*!sc*/
# data-styled.g531[id="style__FirstMenuContainer-sc-1jp0bkg-1"]{content:"jbSeHF,"}/*!sc*/
# .blYOWW{display:none;margin-top:20px;margin-left:12px;margin-right:12px;height:1px;background-color:#edeff0;}/*!sc*/
# @media (max-width:1023px){.blYOWW{display:block;}}/*!sc*/
# data-styled.g532[id="style__Line-sc-1jp0bkg-2"]{content:"blYOWW,"}/*!sc*/
# .hZDsRP{margin-top:24px;}/*!sc*/
# @media (max-width:1023px){.hZDsRP{padding:0 12px;}}/*!sc*/
# data-styled.g533[id="style__SecondRow-sc-1jp0bkg-3"]{content:"hZDsRP,"}/*!sc*/
# .gFKfmL{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:baseline;-webkit-box-align:baseline;-ms-flex-align:baseline;align-items:baseline;margin-top:24px;}/*!sc*/
# @media (max-width:1023px){.gFKfmL{margin-top:0;border-top:1px solid #f8f8f9;padding-top:16px;}}/*!sc*/
# data-styled.g534[id="style__SecondRowFirstMenuContainer-sc-1jp0bkg-4"]{content:"gFKfmL,"}/*!sc*/
# .fcicKE{margin-top:24px;}/*!sc*/
# @media (max-width:1023px){.fcicKE{margin-top:16px;padding-top:16px;border-top:1px solid #f8f8f9;}}/*!sc*/
# data-styled.g535[id="style__SecondRowSecondMenuContainer-sc-1jp0bkg-5"]{content:"fcicKE,"}/*!sc*/
# .gFhXja{font-style:normal;font-weight:normal;font-size:14px;line-height:20px;-webkit-letter-spacing:-0.15px;-moz-letter-spacing:-0.15px;-ms-letter-spacing:-0.15px;letter-spacing:-0.15px;color:#616568;font-feature-settings:'case' on,'ss02' on;margin-top:20px;}/*!sc*/
# data-styled.g536[id="style__Description-sc-1jp0bkg-6"]{content:"gFhXja,"}/*!sc*/
# .dTJigN{color:#1b1c1d;padding:8px 0;margin-top:12px;display:inline-block;cursor:pointer;}/*!sc*/
# data-styled.g538[id="style__GlobalDescription-sc-1jp0bkg-8"]{content:"dTJigN,"}/*!sc*/
# .gpivut{color:#1b1c1d;margin-bottom:8px;padding-left:12px;font-size:16px;line-height:24px;}/*!sc*/
# data-styled.g539[id="style__Title-sc-1jp0bkg-9"]{content:"gpivut,"}/*!sc*/
# .eVRqBu{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}/*!sc*/
# data-styled.g540[id="style__ExternalLink-sc-1jp0bkg-10"]{content:"eVRqBu,"}/*!sc*/
# .hsAGeA{color:#1b1c1d;-webkit-flex:1;-ms-flex:1;flex:1;padding:8px 12px;}/*!sc*/
# data-styled.g541[id="style__LinkTitle-sc-1jp0bkg-11"]{content:"hsAGeA,"}/*!sc*/
# .iUTWRh{margin-top:12px;display:none;color:#858a8d;text-align:center;}/*!sc*/
# @media (min-width:1024px){.iUTWRh{display:block;}}/*!sc*/
# data-styled.g542[id="style__CSDescription-sc-1jp0bkg-12"]{content:"iUTWRh,"}/*!sc*/
# .fcPoKv{border-radius:3px;font-style:normal;font-weight:bold;font-size:14px;line-height:20px;text-align:center;-webkit-letter-spacing:-0.15px;-moz-letter-spacing:-0.15px;-ms-letter-spacing:-0.15px;letter-spacing:-0.15px;font-feature-settings:'case' on,'ss02' on;padding:0;box-sizing:border-box;width:100%;height:40px;color:#1b1c1d;}/*!sc*/
# @media (max-width:1023px){.fcPoKv:hover{background-color:#f8f8f9;}}/*!sc*/
# data-styled.g543[id="style__CSButton-sc-1jp0bkg-13"]{content:"fcPoKv,"}/*!sc*/
# .YfvSR{display:block;float:right;margin:0;padding-right:12px;line-height:24px;color:#858a8d;}/*!sc*/
# @media (min-width:1024px){.YfvSR{display:none;}}/*!sc*/
# data-styled.g544[id="style__CSDescriptionMobile-sc-1jp0bkg-14"]{content:"YfvSR,"}/*!sc*/
# .fRGcZJ{margin-left:12px;}/*!sc*/
# @media (max-width:1023px){.fRGcZJ{margin-right:12px;}}/*!sc*/
# data-styled.g545[id="style__CSContainer-sc-1jp0bkg-15"]{content:"fRGcZJ,"}/*!sc*/
# .hhXFXO{clear:both;}/*!sc*/
# data-styled.g546[id="style__TitleContainer-sc-1jp0bkg-16"]{content:"hhXFXO,"}/*!sc*/
# .cQReuQ{float:left;}/*!sc*/
# data-styled.g547[id="style__CSTitle-sc-1jp0bkg-17"]{content:"cQReuQ,"}/*!sc*/
# .kxpDkf{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;overflow:hidden;}/*!sc*/
# data-styled.g548[id="style__SmallLinkContainer-sc-1jp0bkg-18"]{content:"kxpDkf,"}/*!sc*/
# .gKPWwn{margin-left:-24px;}/*!sc*/
# data-styled.g549[id="style__SmallLinkInner-sc-1jp0bkg-19"]{content:"gKPWwn,"}/*!sc*/
# .dvUkWr{font-style:normal;font-weight:normal;font-size:11px;line-height:16px;font-feature-settings:'case' on,'ss02' on;display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;color:#858a8d;}/*!sc*/
# .dvUkWr:before{display:block;width:24px;text-align:center;content:'･';}/*!sc*/
# .dvUkWr:hover{color:'inherit';-webkit-text-decoration:none;text-decoration:none;}/*!sc*/
# data-styled.g550[id="style__SmallLink-sc-1jp0bkg-20"]{content:"dvUkWr,"}/*!sc*/
# .cvGYR{font-style:normal;font-weight:normal;font-size:9px;line-height:12px;font-feature-settings:'case' on,'ss02' on;color:#a8aeb3;margin-top:16px;}/*!sc*/
# data-styled.g551[id="style__IncDescription-sc-1jp0bkg-21"]{content:"cvGYR,"}/*!sc*/
# .gzGZbk{position:relative;}/*!sc*/
# @media (max-width:1023px){.gzGZbk{padding:0 12px;}}/*!sc*/
# data-styled.g552[id="style__FooterContainer-sc-1jp0bkg-22"]{content:"gzGZbk,"}/*!sc*/
# .bsHxGj{-webkit-box-flex:0;-webkit-flex-grow:0;-ms-flex-positive:0;flex-grow:0;width:100%;margin-top:24px;}/*!sc*/
# data-styled.g553[id="style__MenuContainer-sc-1jp0bkg-23"]{content:"bsHxGj,"}/*!sc*/
# .hmYapu{margin-top:16px;font-weight:bold;}/*!sc*/
# @media (max-width:1023px){.hmYapu:hover{background-color:#f8f8f9;}}/*!sc*/
# data-styled.g554[id="style__AppDownloadButton-sc-1jp0bkg-24"]{content:"hmYapu,"}/*!sc*/
# .gZyTLs{border-top:1px solid #edeff0;background-color:#FFF;padding-bottom:32px;}/*!sc*/
# @media (min-width:1024px){.gZyTLs{padding-top:40px;padding-bottom:64px;}}/*!sc*/
# @media (max-width:1023px){.gZyTLs{padding-bottom:72px;}}/*!sc*/
# ...
# 저희가 강의중에 다루지 않았던 비즈왁스를 이용해서 캔들을 제작하고 싶은데요. 비즈왁스를 다룰 때의 주의사항과 프래그런스 오일 첨가 %, 향첨가 온도, 붓기 온도, 색첨가 온도 등에 대해 자세히 알고 싶습니다. 또한 필라 캔들을 만들 때 몇대 몇 비율로 혼합하는 것이 좋은지, 이렇게 혼합할 때도 호호바오일을 넣어야하는지 궁금합니다.
# 제가 비염이 심하고 호흡기 질환이 있어 관심이 많이 가네요:-)</div><div class="sc-dQppl ijMXBg" color="#a8aeb3">Swan님의 글</div></div></div></div></a><a class="LinkComponent__StyledLink-gmbdn6-1 hYxdXM sc-dlfnbm bcaJjD PostMediaItem-a2b40z-0 gfBdMF" href="/klasses/5c6f91cf74eabcfdafa1e3b4/posts/5d5406f75c722e280a56d17e/?from=PRODUCT_DETAIL"><span class="RatioImage__Container-sc-1riu4nv-0 hjzEDS Thumbnail-sc-1sevrw-0 dxYbvt"></span></a><a class="LinkComponent__StyledLink-gmbdn6-1 hYxdXM sc-dlfnbm bcaJjD PostMediaItem-a2b40z-0 gfBdMF" href="/klasses/5c6f91cf74eabcfdafa1e3b4/posts/5f8d1064ae9c3d001a49277e/?from=PRODUCT_DETAIL"><span class="RatioImage__Container-sc-1riu4nv-0 hjzEDS Thumbnail-sc-1sevrw-0 dxYbvt"></span></a><a class="LinkComponent__StyledLink-gmbdn6-1 hYxdXM sc-dlfnbm bcaJjD PostMediaItem-a2b40z-0 eGsmXW" href="/klasses/5c6f91cf74eabcfdafa1e3b4/posts"><div class="ThumbnailOverlay-sc-77phk-0 dVlREr"><div class="RatioContainer__Container-sc-1v4i457-0 iGIdiM PostReviewCardListfragment__QuoteCardRatioContainer-wlomfr-1 fzYDa-d" radius="3"><div class="RatioContainer__Inner-sc-1v4i457-1 ejYLNp"><div class="QuoteCard__Container-jfv8zg-1 eoqYAX PostReviewCardListfragment__PostReviewQuoteCard-wlomfr-2 fizXVy"><svg class="QuoteCard__QuoteIcon-jfv8zg-0 daZFJR" fill="none" height="12" viewbox="0 0 24 24" width="12"><path clip-rule="evenodd" d="M.899 14.526l.001.21C.9 17.75 3.239 20 6 20a5 5 0 100-10c-.244 0-.527.027-.717.1C5.706 8.243 6.518 6.317 8 4H5.5a28.473 28.473 0 00-2.932 4.28C1.613 9.97.9 12 .9 14.315c-.002.057-.002.12-.001.212zm12 0l.001.21C12.9 17.75 15.239 20 18 20a5 5 0 100-10c-.244 0-.527.027-.717.1C17.706 8.243 18.518 6.317 20 4h-2.5a28.466 28.466 0 00-2.932 4.28C13.613 9.97 12.9 12 12.9 14.315c-.002.057-.002.12-.001.212z" fill="#1B1C1D" fill-rule="evenodd"></path></svg><div class="QuoteCard__Content-jfv8zg-2 kDgPDe">잘부탁드립니다 :) 선생님의 강의 하나하나 놓치지않을거에요요요오오 😇 재료 빨리 도착하길 🙏🏻</div><div class="sc-dQppl ijMXBg" color="#a8aeb3">다 현님의 글</div></div></div></div></div></a></div><div class="Spacing__Box-sc-47wgmh-0 cwFQdY"><div class="sc-eJMQSu jAeAvM"><hr class="sc-nFpLZ kQhlQU" color="#edeff0"/></div></div><div class="Spacing__Box-sc-47wgmh-0 jTmoQW"><section class="UserProfile__ProfileContainer-uvkg4s-0 dyFQdb"><div class="ProfileImage__Container-sc-1wrfv3c-0 eqzySZ" size="40"><span class="RatioImage__Container-sc-1riu4nv-0 bHVtPL ProfileImage__UserProfileImage-sc-1wrfv3c-1 hSdEji"></span><div class="Sticker__StickerContainer-jn8189-1 kslSaU"><svg fill="none" height="10" viewbox="0 0 24 24" width="10"><path clip-rule="evenodd" d="M2 10.68c0-.691.503-1.251 1.135-1.251h2.273V22H3.135C2.508 22 2 21.427 2 20.749v-10.07zM13.361 8.17h6.367c1.255 0 2.272 1.126 2.272 2.515 0 .15-.012.301-.037.45l-1.615 9.832C20.25 21.566 19.779 22 19.23 22H7.68V9.429L11.09 0c1.703 0 2.84 1.257 2.84 3.143 0 1.257-.19 2.933-.569 5.028z" fill="#FFF" fill-rule="evenodd"></path></svg></div></div><div class="UserProfile__ProfileInfoArea-uvkg4s-1 bbntjE"><strong class="UserProfile__NameText-uvkg4s-2 hDRfNY">문**</strong><div class="UserProfile__SubTitleText-uvkg4s-3 kRSfeP">2/27/2021</div></div></section><div class="sc-dQppl kgbqfx UserMissionFeedbackItemExperimentalfragment__Comment-sc-1bqsmt7-0 jyTxqj">쉽고 차분하게 설명해주셔서 귀에 쏙쏙 들어와서 이해도 잘 되고 좋아요 ♡</div></div><div class="Spacing__Box-sc-47wgmh-0 jTmoQW"><section class="UserProfile__ProfileContainer-uvkg4s-0 dyFQdb"><div class="ProfileImage__Container-sc-1wrfv3c-0 eqzySZ" size="40"><span class="RatioImage__Container-sc-1riu4nv-0 bHVtPL ProfileImage__UserProfileImage-sc-1wrfv3c-1 hSdEji"></span><div class="Sticker__StickerContainer-jn8189-1 kslSaU"><svg fill="none" height="10" viewbox="0 0 24 24" width="10"><path clip-rule="evenodd" d="M2 10.68c0-.691.503-1.251 1.135-1.251h2.273V22H3.135C2.508 22 2 21.427 2 20.749v-10.07zM13.361 8.17h6.367c1.255 0 2.272 1.126 2.272 2.515 0 .15-.012.301-.037.45l-1.615 9.832C20.25 21.566 19.779 22 19.23 22H7.68V9.429L11.09 0c1.703 0 2.84 1.257 2.84 3.143 0 1.257-.19 2.933-.569 5.028z" fill="#FFF" fill-rule="ev ...
#               window.__APOLLO_STATE__ = {"FeatureFlag:603c7315da8b60000e09fca9":{"_id":"603c7315da8b60000e09fca9","__typename":"FeatureFlag","flagId":"MAGIC_CART_ENABLED","enableFlag":true},"ROOT_QUERY":{"__typename":"Query","featureFlagByFlagId({\"flagId\":\"MAGIC_CART_ENABLED\"})":{"__ref":"FeatureFlag:603c7315da8b60000e09fca9"},"featureFlagByFlagId({\"flagId\":\"MAGIC_CART_TOOLTIP\"})":{"__ref":"FeatureFlag:603c731b1c5e02000e0f8c6c"},"getPromotionTodayFreeKlasses":[{"__ref":"PromotionFreeKlass:603ddfcff83a012c6df96e9e"}],"featureFlagByFlagId({\"flagId\":\"WELCOME_KLASS101_MODAL\"})":{"__ref":"FeatureFlag:5f9810c26a80f04406222bd5"},"featureFlagByFlagId({\"flagId\":\"AD_RECIEVE_AGREEMENT_MODAL\"})":{"__ref":"FeatureFlag:5f3b68aa953ae8973bd8789c"},"featureFlagByFlagId({\"flagId\":\"WELCOME_TO_CLASS_101\"})":{"__ref":"FeatureFlag:5fcdf22df416ec000d7a5c48"},"productById({\"productId\":\"HecSpAww7RHFuLUzqBjR\"})":{"__ref":"Product:5c5d780774eabcfdafd39109"},"getActivePromotionTopBanners":[{"__ref":"PromotionTopBanner:603c6ae235d4ff000e6cfc6f"}],"popularKeywordsForProduct({})":{"__typename":"PopularProductSearchQueryList","queryList":[{"__typename":"PopularProductSearchQuery","keyword":"아이패드","rankPreviousDiff":0},{"__typename":"PopularProductSearchQuery","keyword":"디지털 드로잉","rankPreviousDiff":0},{"__typename":"PopularProductSearchQuery","keyword":"일러스트","rankPreviousDiff":0},{"__typename":"PopularProductSearchQuery","keyword":"부동산","rankPreviousDiff":0},{"__typename":"PopularProductSearchQuery","keyword":"뜨개질","rankPreviousDiff":0},{"__typename":"PopularProductSearchQuery","keyword":"베이킹","rankPreviousDiff":0},{"__typename":"PopularProductSearchQuery","keyword":"이모티콘","rankPreviousDiff":2},{"__typename":"PopularProductSearchQuery","keyword":"드로잉","rankPreviousDiff":0},{"__typename":"PopularProductSearchQuery","keyword":"포토샵","rankPreviousDiff":-2},{"__typename":"PopularProductSearchQuery","keyword":"자수","rankPreviousDiff":0}],"generatedAt":"2021-03-03T04:45:00.000Z"},"getAvailableRecommendSearchKeywords":[{"__typename":"RecommendSearchKeyword","searchKeywords":["24시간 최저가","명예의 전당","준비물 무료","전통문화할인","TOP20","BIG이용권","선물하기 전액 환급","선착순 증정"]}],"postsForReviewSection({\"klassId\":\"5c6f91cf74eabcfdafa1e3b4\"})":[{"__ref":"Post:5f5461d2cebf33000d93098e"},{"__ref":"Post:5f1487da35a842354ea87987"},{"__ref":"Post:5e26e0dc8bfaa745c2ee897c"},{"__ref":"Post:5f76c13a5d8dca0015ff778c"},{"__ref":"Post:5ed608e6943e74631a1d1817"},{"__ref":"Post:5d5406f75c722e280a56d17e"},{"__ref":"Post:5f8d1064ae9c3d001a49277e"},{"__ref":"Post:5f5754c1416b4f0028f19e19"}],"userMissionFeedbackCount({\"preFilter\":{\"klassId\":\"5c6f91cf74eabcfdafa1e3b4\"}})":640,"userMissionFeedbackCount({\"preFilter\":{\"klassId\":\"5c6f91cf74eabcfdafa1e3b4\",\"status\":\"GOOD\"}})":629,"userMissionFeedbackCount({\"preFilter\":{\"klassId\":\"5c6f91cf74eabcfdafa1e3b4\",\"status\":\"BAD\"}})":11,"userMissionFeedbacks({\"limit\":2,\"offset\":0,\"preFilter\":{\"klassId\":\"5c6f91cf74eabcfdafa1e3b4\",\"status\":\"GOOD\"}})":[{"__ref":"UserMissionFeedback:6039eeb7adcf73000e2f5faf"},{"__ref":"UserMissionFeedback:60102a77cd6ead0014cf1e30"}],"featureFlagByFlagId({\"flagId\":\"subscription-HecSpAww7RHFuLUzqBjR\"})":null,"recommendRelatedProducts({\"id\":\"HecSpAww7RHFuLUzqBjR\",\"standard\":\"productView\"})":[{"__ref":"Product:5d4bcb42e6ec6f454f37f435"},{"__ref":"Product:5e880b2b118f090dcf31b454"},{"__ref":"Product:5f729a11b456a6001bbedc94"},{"__ref":"Product:5e7c08f2058d5537a34f907d"},{"__ref":"Product:5c5d780874eabcfdafd3937b"}],"productById({\"productId\":\"5c5d780774eabcfdafd39109\"})":{"__ref":"Product:5c5d780774eabcfdafd39109"},"featureFlagByFlagId({\"flagId\":\"PRODUCT_KLASS_SUMMARY_SECTION\"})":{"__ref":"FeatureFlag:5f1567bc912b664865f9e72d"},"klassById({\"klassId\":\"5c6f91cf74eabcfdafa1e3b4\"})":{"__ref":"Klass:5c6f91cf74eabcfdafa1e3b4"},"featureFlagByFlagId({\"flagId\":\"subscription-HecSpAww7RHFuLUzqBjR-stock\"})":null,"featureFlagByFlagId({\"flagId\":\"VIMEO_AUTO_PLAY\"})":nul ...
#           </script><script>
#               if (typeof window.__REACT_DEVTOOLS_GLOBAL_HOOK__ === 'object') {
#                  __REACT_DEVTOOLS_GLOBAL_HOOK__.inject = function() {};
#               }
#           </script><script crossorigin="true" src="/static/js/client.05586090.chunk.js"></script><script crossorigin="true" id="__LOADABLE_REQUIRED_CHUNKS__" type="application/json">[66,3,0,1,2,6]</script><script crossorigin="true" id="__LOADABLE_REQUIRED_CHUNKS___ext" type="application/json">{"namedChunks":["i18n-ko-json","MainPageHeroBanner","ProductViewPage"]}</script><script async="" crossorigin="true" data-chunk="client" src="/static/js/bundle.3a7a82f2.js"></script><script async="" crossorigin="true" data-chunk="client" src="/static/js/vendors.644078f6.chunk.js"></script><script async="" crossorigin="true" data-chunk="client" src="/static/js/vendors~client.516c4eb4.chunk.js"></script><script async="" crossorigin="true" data-chunk="client" src="/static/js/client.05586090.chunk.js"></script><script async="" crossorigin="true" data-chunk="MainPageHeroBanner" src="/static/js/MainPageHeroBanner.af6695f9.chunk.js"></script><script async="" crossorigin="true" data-chunk="ProductViewPage" src="/static/js/vendors~CategoryPage~EarlybirdPage~KlassPage~MagazineViewPage~MoneyPage~MyPage~PostViewPage~Signatur~4606a067.af542be6.chunk.js"></script><script async="" crossorigin="true" data-chunk="ProductViewPage" src="/static/js/vendors~KlassPage~MoneyPage~PostNewPage~PostViewPage.fefd934d.chunk.js"></script><script async="" crossorigin="true" data-chunk="ProductViewPage" src="/static/js/vendors~KlassPage~MagazineViewPage~PostNewPage~PostViewPage.02de0ea7.chunk.js"></script><script async="" crossorigin="true" data-chunk="ProductViewPage" src="/static/js/PostViewPage.fed46ee7.chunk.js"></script><div id="portal"></div><div id="global-portal-area"></div><div id="ch-plugin"></div><script src="/vendor/naverlogin.min.js" type="text/javascript"></script><script src="//developers.kakao.com/sdk/js/kakao.min.js" type="text/javascript"></script><script async="" src="//static.criteo.net/js/ld/ld.js" type="text/javascript"></script><script type="text/javascript">Kakao.init('bb2203fc061b5da4a9e1152da81610e1');</script><script type="application/ld+json">{
#     "@context": "http://schema.org",
#     "@type": "Organization",
#     "name": "Class101",
#     "email": "mailto:ask@class101.net",
#     "url": "https://class101.net",
#     "sameAs": [
#       "https://www.instagram.com/class101_official",
#       "https://twitter.com/Class101Korea",
#       "https://www.facebook.com/Class101Korea/",
#       "https://itunes.apple.com/kr/app/class101-클래스101/id1320607634",
#       "https://play.google.com/store/packages/details?id=net.pedaling.class101",
#       "https://tv.naver.com/class101",
#       "https://pf.kakao.com/_xcxmxgcxl",
#       "https://www.youtube.com/channel/UCDJ1ZXSnt37KLaLFPFlBkqw"
#     ]
#   }</script><script>window.channelPluginSettings = {
#     pluginKey: '4b19a129-f419-450e-8b38-3d0339f895eb',
#     zIndex: 1000,
#   };
#   (function () {
#     var w = window;
#     if (w.ChannelIO) {
#       return (window.console.error || window.console.log || function () {})('ChannelIO script included twice.');
#     }
#     var d = window.document;
#     var ch = function () {
#       ch.c(arguments);
#     };
#     ch.q = [];
#     ch.c = function (args) {
#       ch.q.push(args);
#     };
#     w.ChannelIO = ch;
#     function l() {
#       if (w.ChannelIOInitialized) {
#         return;
#       }
#       w.ChannelIOInitialized = true;
#       var s = document.createElement('script');
#       s.type = 'text/javascript';
#       s.async = true;
#       s.src = 'https://cdn.channel.io/plugin/ch-plugin-web.js';
#       s.charset = 'UTF-8';
#       var x = document.getElementsByTagName('script')[0];
#       x.parentNode.insertBefore(s, x);
#     }
#     if (document.readyState === 'complete') {
#       l();
#     } else if (window.attachEvent) {
#       window.attachEvent('onload', l);
#     } else {
#       window.addEventListener('DOMContentLoaded', l, false);
#       window.addEventListener('load', l, false);
#     }
#   })();</script><script type="text/javascript">
#   (function () {
#     var w = window;
#     var ic = w.Intercom;
#     if (typeof ic === 'function') {
#         ic('reattach_activator');
#         ic('update', w.intercomSettings);
#     } else {
#         var d = document;
#         var i = function () {
#             i.c(arguments);
#         };
#         i.q = [];
#         i.c = function (args) {
#             i.q.push(args);
#         };
#         w.Intercom = i;
#         var l = function () {
#             var s = d.createElement('script');
#             s.type = 'text/javascript';
#             s.async = true;
#             s.src = 'https://widget.intercom.io/widget/' + 'unjfsjy5';
#             var x = d.getElementsByTagName('script')[0];
#             x.parentNode.insertBefore(s, x);
#         };
#         if (w.attachEvent) {
#             w.attachEvent('onload', l);
#         } else {
#             w.addEventListener('load', l, false);
#         }
#     }
#   })();</script><script src="/vendor/outdated-browser.min.js" type="text/javascript"></script><script src="https://code.jquery.com/jquery-1.12.4.min.js" type="text/javascript"></script></body></html>

# %%
//*[@id="wrapper"]/div[1]/main/div/div[2]/div/div[1]/div[1]/div[1]/h2
